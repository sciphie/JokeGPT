# %%
import pandas as pd

path = 'joke_explanation'
df = pd.read_pickle(path)
print(df.shape)
df
# Out:
# (44, 2)
#                                               prompt  \
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# 0  Can you explain why this joke is funny: \n\n W...
# ...

# %%
df.response.to_list()
# Out:
# [{'message': 'This joke is funny because it\'s a play on words. The word "problems" is being used in two different ways: as a mathematical term (referring to mathematical exercises) and as an idiomatic expression (referring to difficulties or challenges in life). The joke is that the math book is "sad" because it has a lot of mathematical exercises, which are referred to as "problems", but in this context, the word "problems" is also being used to suggest that the book is overwhelmed or unhappy. The humor comes from the pun, or the play on words.\n\n',
#   'conversation_id': '81d6e391-0745-4188-87d6-615119d6274c'},
# ...
