# %%
import pandas as pd

path = 'joke_explanation'
df = pd.read_pickle(path)
print(df.shape)
df.shape
# Out:
# (44, 2)
# (44, 2)

# %%
for i in [0,2,3]: 
    print('###### Question ######')
    print(df.iloc[i,0], '\n\n')
    print('answer: ', df.iloc[i,1]['message'])
# Out:
# ###### Question ######
# Can you explain why this joke is funny:
#
#  Why was the math book sad? Because it had too many problems.
#
#
# answer:  This joke is funny because it's a play on words. The word "problems" is being used in two different ways: as a mathematical term (referring to mathematical exercises) and as an idiomatic expression (referring to difficulties or challenges in life). The joke is that the math book is "sad" because it has a lot of mathematical exercises, which are referred to as "problems", but in this context, the word "problems" is also being used to suggest that the book is overwhelmed or unhappy. The humor comes from the pun, or the play on words.
#
#
# ###### Question ######
# Can you explain why this joke is funny:
#
#  Why was the math book sad? Because it had too many problems.
#
#
# answer:  This joke is a play on words, using the double meaning of the word "problems." In mathematics, a problem is an exercise to be solved. In everyday language, "problems" can also refer to difficulties or challenges in life. In the joke, the math book is sad because it has too many mathematical problems, but the word "problems" is also being used in the sense of difficulties or challenges in life, implying that the book is overwhelmed or unhappy. The humor comes from the pun of using the same word to convey two different meanings.
#
#
# ###### Question ######
# Can you explain why this joke is funny:
#
#  Why was the math book sad? Because it had too many problems.
#
#
# answer:  This joke is a pun, relying on the double meaning of the word "problems." On one hand, in mathematics, "problems" are mathematical exercises to be solved. On the other hand, in everyday language, "problems" can also refer to difficulties or challenges in life. The joke is that the math book is sad because it has too many mathematical problems, but the word "problems" is also being used to suggest that the book is overwhelmed or unhappy. The humor is created by the use of the same word with two different meanings in the same context.

# %%
import pandas as pd

path = 'joke_detection'
df = pd.read_pickle(path)
print(df.shape)
df.shape
# Out:
# (74, 2)
# (74, 2)

# %%
for i in range(68): 
    print('###### Question ######')
    print(df.iloc[i,0], '\n\n')
    print('answer: ', df.iloc[i,1]['message'])
# Out:
# ###### Question ######
# What kind of sentence is that: Why did the scarecrow win an award? Because he was outstanding in his field.
#
#
# answer:  The sentence "Why did the scarecrow win an award? Because he was outstanding in his field." is a joke or a pun in the form of a question-answer format. The answer "Because he was outstanding in his field." is a play on words as "outstanding" can mean both "excellent" and "standing outside". The joke refers to the fact that the scarecrow is a figure often made to stand in fields to scare away birds.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the tomato turn red? Because it saw the salad dressing.
#
#
# answer:  The sentence "Why did the tomato turn red? Because it saw the salad dressing." is also a joke or a pun. The answer "Because it saw the salad dressing." is a play on words, as "saw" can mean both "observed" and "cut", and the joke is based on the idea that the tomato, being a type of fruit, turned red due to the embarrassment it felt when it saw the salad dressing. This joke is an example of a type of humor known as a "groaner" because the punchline is predictable and often elicits a groan from the audience.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the math book sad? Because it had too many problems.
#
#
# answer:  The sentence "Why was the math book sad? Because it had too many problems." is another joke or pun. The answer "Because it had too many problems." is a play on words, as "problems" can mean both mathematical problems and difficulties. The joke is based on the idea that the math book is unhappy because it contains too many challenging mathematical problems for the reader to solve. This type of joke is a common example of word play and is often used to lighten up a conversation or bring a smile to someone's face.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't scientists trust atoms? Because they make up everything.
#
#
# answer:  The sentence "Why don't scientists trust atoms? Because they make up everything." is a joke or a pun. The answer "Because they make up everything." is a play on words, as "make up" can mean both "compose" and "fabricate". The joke is based on the idea that atoms are the basic building blocks of matter, and that scientists don't trust them because everything is made up of atoms and they can be used to explain or describe everything. The joke is a lighthearted take on the importance of atoms in science and the vastness of their applications in explaining the natural world.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the cookie go to the doctor? Because it was feeling crumbly.
#
#
# answer:  The sentence "Why did the cookie go to the doctor? Because it was feeling crumbly." is a joke or a pun. The answer "Because it was feeling crumbly." is a play on words, as "crumbly" can mean both "falling apart" and "having crumbs". The joke is based on the idea that the cookie was in a state of disrepair, either physically or emotionally, and needed to see a doctor. This type of joke is often used to bring a smile to someone's face and to add some lighthearted humor to a conversation.
#
#
# ###### Question ######
# What kind of sentence is that: Why couldn't the bicycle stand up by itself? Because it was two-tired.
#
#
# answer:  The sentence "Why couldn't the bicycle stand up by itself? Because it was two-tired." is a joke or a pun. The answer "Because it was two-tired." is a play on words, as "two-tired" sounds like "too tired". The joke is based on the idea that the bicycle is exhausted and unable to stand on its own because it has two tires. This type of joke is often used to bring a smile to someone's face and to add some lighthearted humor to a conversation.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the frog call his insurance company? He had a jump in his car.
#
#
# answer:  The sentence "Why did the frog call his insurance company? He had a jump in his car." is a joke or a pun. The answer "He had a jump in his car." is a play on words, as "jump" can mean both a sudden movement and a boost of electrical energy to start a car engine. The joke is based on the idea that the frog had some kind of problem with his car and needed to call his insurance company for assistance. This type of joke is often used to bring a smile to someone's face and to add some lighthearted humor to a conversation.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the chicken cross the playground? To get to the other slide.
#
#
# answer:  The sentence "Why did the chicken cross the playground? To get to the other slide." is a joke or a pun. The answer "To get to the other slide." is a play on words, as it refers to the children's playground activity of sliding down a slide. The joke is based on the idea that the chicken is crossing the playground to reach the other slide, implying that the chicken is a playful or adventurous animal. This type of joke is often used to bring a smile to someone's face and to add some lighthearted humor to a conversation.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the computer cold? Because it left its Windows open.
#
#
# answer:  The sentence "Why did the chicken cross the playground? To get to the other slide." is a joke or a pun. The answer "To get to the other slide." is a play on words, as it refers to the children's playground activity of sliding down a slide. The joke is based on the idea that the chicken is crossing the playground to reach the other slide, implying that the chicken is a playful or adventurous animal. This type of joke is often used to bring a smile to someone's face and to add some lighthearted humor to a conversation.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't oysters give to charity? Because they're shellfish.
#
#
# answer:  That sentence is a joke in the form of a pun. The word "shellfish" is a play on the word "selfish," suggesting that the reason oysters do not give to charity is because they are considered greedy or ungenerous.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a virus.
#
#
# answer:  That sentence is a joke in the form of a pun. The word "virus" is a play on the word "virus," which is a term used to describe malicious software that can infect a computer system and cause problems. The joke is that the computer went to the doctor because it was experiencing issues that were caused by a "virus."
#
#
# ###### Question ######
# What kind of sentence is that: Why did the banana go to the doctor? Because it wasn't peeling well.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "wasn't peeling well" is a play on the word "feeling," implying that the banana was experiencing some kind of health issue. The joke is that the banana went to the doctor because it was having trouble peeling, as if it were a human experiencing a physical ailment.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the coffee file a police report? Because it got mugged.
#
#
# answer:  That sentence is a joke in the form of a pun. The word "mugged" is a play on the word "mug," which is a term used to describe a cup or container used to hold hot beverages such as coffee. The joke is that the coffee filed a police report because it was "mugged," or taken out of its container, implying that it was stolen or taken without permission.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the golfer bring two pairs of pants? In case he got a hole in one.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "got a hole in one" is a play on the golfing term "hole in one," which refers to a shot that goes directly into the hole on a golf course. The joke is that the golfer brought two pairs of pants because he was worried about getting a "hole in one," implying that he might accidentally rip or tear his pants, which is why he brought a backup pair.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man put his money in the freezer? He wanted cold hard cash.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "cold hard cash" is a play on words, combining the idea of money that is "hard" or tangible with the idea of something being "cold," as in stored in a refrigerator or freezer. The joke is that the man put his money in the freezer because he wanted "cold hard cash," implying that he wanted his money to be both tangible and well-preserved.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't seagulls fly over the bay? Because then they'd be bagels.
#
#
# answer:  That sentence is a joke in the form of a pun. The word "bagels" is a play on the words "bay" and "gulls," suggesting that if seagulls flew over the bay, they would be "bay-gulls," or "bagels." The joke is that the seagulls don't fly over the bay because they would become "bagels," which is an absurd idea.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the chicken go to the seance? To talk to the other side.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "to talk to the other side" is a play on the idea of a seance, which is a gathering where people attempt to communicate with spirits or entities from beyond the physical world. The joke is that the chicken went to the seance "to talk to the other side," implying that it wanted to communicate with the afterlife, even though chickens are a type of animal and not typically thought of as having the ability to communicate with the spirit world.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the belt sent to jail? Because it held up a pair of pants.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "held up a pair of pants" is a play on the phrase "held up," which is another way of saying "robbed" or "stole." The joke is that the belt was sent to jail because it "held up a pair of pants," implying that it committed a crime by supporting the pants and keeping them up.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the chicken cross the road? To get to the other side.
#
#
# answer:  That sentence is a classic joke in the form of a riddle. The punchline, "to get to the other side," is a play on the idea that the answer to the riddle is unexpected or absurd. The joke is that the question is a set-up for a seemingly straightforward answer, but the answer is not what one might initially expect, making the joke amusing or surprising.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a byte.
#
#
# answer:  That sentence is a joke in the form of a pun. The word "byte" is a play on the words "bite" and "byte," which is a unit of digital information used in computing. The joke is that the computer went to the doctor because it had a "byte," implying that it was suffering from a small amount of digital information, which is a humorous idea.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the cow go to outer space? To see the moooon.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "see the moooon" is a play on the word "moon," with "moo" being the sound that a cow makes. The joke is that the cow went to outer space to "see the moooon," implying that it wanted to observe a celestial object that is shaped like a crescent and makes a "moo" sound, which is an absurd idea.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man put his money in the blender? He wanted to make liquid assets.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "liquid assets" is a play on words, combining the idea of assets that are easily convertible into cash with the idea of something being "liquid," as in a fluid or smooth consistency. The joke is that the man put his money in the blender because he wanted to make "liquid assets," implying that he wanted to convert his money into a fluid or smooth consistency, which is a humorous idea.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't skeletons fight each other? They don't have the guts.
#
#
# answer:  That sentence is a joke in the form of a pun. The phrase "don't have the guts" is a play on words, combining the idea of bravery or fortitude with the idea of the internal organs located in the abdominal cavity of a human or animal. The joke is that skeletons don't fight each other because they "don't have the guts," implying that they lack the internal organs necessary for bravery or fortitude, which is a humorous idea.
#
#
# ###### Question ######
# What kind of sentence is that: What do you call an alligator in a vest? An investigator.
#
#
# answer:  That sentence is a joke in the form of a pun. The word "investigator" is a play on words, combining the idea of a person who investigates or examines something with the word "investigator," which is someone who investigates a crime or a matter of public concern. The joke is that an alligator wearing a vest is called an "investigator," implying that it is a detective or a private eye, which is a humorous idea.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the scarecrow win an award? Because he did very good work.
#
#
# answer:  The sentence "Why did the scarecrow win an award? Because he did very good work." is an example of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the scarecrow win an award?" is a question and the second part "Because he did very good work." is the answer.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the tomato turn red? Because it had a lot sun recently.
#
#
# answer:  The sentence "Why did the tomato turn red? Because it had a lot sun recently." is also an example of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the tomato turn red?" is a question, and the second part "Because it had a lot sun recently." is the answer.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the novel sad? Because it had too many problems.
#
#
# answer:  The sentence "Why was the novel sad? Because it had too many problems." is also an example of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why was the novel sad?" is a question, and the second part "Because it had too many problems." is the answer.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't scientists trust atoms? Because they lied before.
#
#
# answer:  The sentence "Why don't scientists trust atoms? Because they made up everything." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why don't scientists trust atoms?" is a question, and the second part "Because they made up everything." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the cookie go to the doctor? Because it was feeling unwell.
#
#
# answer:  The sentence "Why did the cookie go to the doctor? Because it was feeling unwell." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the cookie go to the doctor?" is a question, and the second part "Because it was feeling unwell." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why couldn't the bicycle stand up by itself? Because it didn't have racks
#
#
# answer:  The sentence "Why couldn't the bicycle stand up by itself? Because it didn't have racks." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why couldn't the bicycle stand up by itself?" is a question, and the second part "Because it didn't have racks." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the frog call his insurance company? He had a scratch in his car.
#
#
# answer:  The sentence "Why did the frog call his insurance company? He had a scratch in his car." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the frog call his insurance company?" is a question, and the second part "He had a scratch in his car." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the computer cold? Because the was broken.
#
#
# answer:  The sentence "Why was the computer cold? Because it was broken." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why was the computer cold?" is a question, and the second part "Because it was broken." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the hipster burn his tongue? He drank too hot coffee.
#
#
# answer:  The sentence "Why did the hipster burn his tongue? He drank too hot coffee." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the hipster burn his tongue?" is a question, and the second part "He drank too hot coffee." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't oysters give to charity? Because they cannot walk.
#
#
# answer:  The sentence "Why don't oysters give to charity? Because they can't walk." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why don't oysters give to charity?" is a question, and the second part "Because they can't walk." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the computer go to the doctor? Because it was sick.
#
#
# answer:  The sentence "Why did the computer go to the doctor? Because it was sick." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the computer go to the doctor?" is a question, and the second part "Because it was sick." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the banana go to the doctor? Because it was sick.
#
#
# answer:  The sentence "Why did the computer go to the doctor? Because it was sick." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the computer go to the doctor?" is a question, and the second part "Because it was sick." is the punchline.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the swimmer bring two pairs of pants? In case he got a hole in one.
#
#
# answer:  The sentence "Why did the swimmer bring two pairs of pants? In case he got a hole in one." is a joke or a pun. The punchline "In case he got a hole in one" is a play on words, as "hole in one" is a term used in golf to describe when a golfer sinks a shot into the hole in one stroke, and in this sentence, it is being used as if the swimmer might get a hole in his pants.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man put his money in the piggy bank? To save some cash.
#
#
# answer:  The sentence "Why did the man put his money in the piggy bank? To save some cash." is a joke or a pun. The punchline "To save some cash" is a play on words, as "save some cash" means to keep or accumulate money, and in this sentence, it is being used as if the man is saving the actual cash by putting it into the piggy bank.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't seagulls fly over the bay? Because then are mostly living in ports.
#
#
# answer:  The sentence "Why don't seagulls fly over the bay? Because then are mostly living in ports." is a joke or a pun. The punchline "Because then are mostly living in ports" is a play on words, as "port" can mean both a place where ships dock and also a direction or orientation, and in this sentence, it is being used to suggest that the seagulls are not flying over the bay because they are oriented towards the ports where they live.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the belt sent to jail? Because it stole a pair of pants.
#
#
# answer:  The sentence "Why was the belt sent to jail? Because it stole a pair of pants." is a joke or a pun. The punchline "Because it stole a pair of pants" is a play on words, as "stole" can mean both to take something without permission and also to support or hold up, and in this sentence, it is being used to suggest that the belt was sent to jail because it took the pants without permission.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the computer go to the doctor? Because it wasn't feeling well.
#
#
# answer:  The sentence "Why did the computer go to the doctor? Because it wasn't feeling well." is a joke or a pun. The punchline "Because it wasn't feeling well" is a play on words, as "feeling well" is a phrase commonly used to describe good health in humans, and in this sentence, it is being used to suggest that the computer, which is a machine, was not functioning properly or was experiencing some kind of technical problem.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the chicken go to outer space? To see the moon.
#
#
# answer:  The sentence "Why did the chicken go to outer space? To see the moon." is a joke or a pun. The punchline "To see the moon" is a play on words, as "to see the moon" is a phrase that can be taken literally to mean observing the moon from a distance, and in this sentence, it is being used to suggest that the chicken went to outer space for this reason, which is absurd.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man put bananas in the blender? He wanted to make a smoothie.
#
#
# answer:  The sentence "Why did the man put bananas in the blender? He wanted to make a smoothie." is a straightforward statement and not a joke or a pun. The man put the bananas in the blender in order to make a smoothie, which is a popular drink made from blending fruit and sometimes other ingredients.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't skeletons fight each other? They are quite peaceful.
#
#
# answer:  The sentence "Why don't skeletons fight each other? They are quite peaceful." is a joke or a pun. The punchline "They are quite peaceful" is a play on words, as "peaceful" is a word used to describe someone or something that is calm and non-violent, and in this sentence, it is being used to suggest that skeletons, which are commonly depicted as scary or frightening, are actually quite peaceful and do not fight with each other.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't skeletons fight each other? They are dead already.
#
#
# answer:  The sentence "Why don't skeletons fight each other? They are dead already." is a joke or a pun. The punchline "They are dead already" is a play on words, as "dead" is a term used to describe someone or something that is no longer alive, and in this sentence, it is being used to suggest that skeletons, which are often depicted as being made of bones, do not fight with each other because they are already dead.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the boy win an award? Because he did very good work.
#
#
# answer:  The sentence "Why did the boy win an award? Because he did very good work." is an example of a question-answer sentence. The first part "Why did the boy win an award?" is a question, and the second part "Because he did very good work." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man turn red? Because he saw the neighbour dressing.
#
#
# answer:  The sentence "Why did the man turn red? Because he saw the neighbor dressing." is also an example of a question-answer sentence, where the first part "Why did the man turn red?" is a question and the second part "Because he saw the neighbor dressing." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the child sad? Because it had too many problems.
#
#
# answer:  The sentence "Why was the child sad? Because it had too many problems." is also a question-answer sentence, where the first part "Why was the child sad?" is a question and the second part "Because it had too many problems." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't scientists trust journalists? Because they make up everything.
#
#
# answer:  The sentence "Why don't scientists trust journalists? Because they make up everything." is also a question-answer sentence, where the first part "Why don't scientists trust journalists?" is a question and the second part "Because they make up everything." is the answer to that question.
#
# It's important to note that the answer given in this sentence is a generalization and not necessarily accurate. Many journalists work hard to report accurately and responsibly, and not all scientists distrust journalists. It's important to be mindful of making broad generalizations, as they can perpetuate harmful stereotypes and misunderstandings.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the woman go to the doctor? Because it was feeling crumbly.
#
#
# answer:  The sentence "Why did the woman go to the doctor? Because she was feeling crumbly." is a question-answer sentence, where the first part "Why did the woman go to the doctor?" is a question and the second part "Because she was feeling crumbly." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why couldn't the kid stand up by itself? Because it was too tired.
#
#
# answer:  The sentence "Why couldn't the kid stand up by itself? Because it was too tired." is a question-answer sentence, where the first part "Why couldn't the kid stand up by itself?" is a question and the second part "Because it was too tired." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the driver call his insurance company? He had a jump in his car.
#
#
# answer:  The sentence "Why did the driver call his insurance company? He had a jump in his car." is a question-answer sentence, where the first part "Why did the driver call his insurance company?" is a question and the second part "He had a jump in his car." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the cild cross the playground? To get to the slide.
#
#
# answer:  The sentence "Why did the child cross the playground? To get to the slide." is a question-answer sentence, where the first part "Why did the child cross the playground?" is a question and the second part "To get to the slide." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the woman cold? Because she left its Windows open.
#
#
# answer:  The sentence "Why was the woman cold? Because she left her windows open." is a question-answer sentence, where the first part "Why was the woman cold?" is a question and the second part "Because she left her windows open." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the coworker burn his tongue? He drank his coffee before it was cool.
#
#
# answer:  The sentence "Why did the coworker burn his tongue? He drank his coffee before it was cool." is a question-answer sentence, where the first part "Why did the coworker burn his tongue?" is a question and the second part "He drank his coffee before it was cool." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't millionaire give to charity? Because he is selfish.
#
#
# answer:  The sentence "Why don't millionaires give to charity? Because they are selfish." is a question-answer sentence, where the first part "Why don't millionaires give to charity?" is a question and the second part "Because they are selfish." is the answer to that question.
#
# It's important to note that this answer is a generalization and not necessarily accurate. Many millionaires do give to charity, and not all who do not give to charity are necessarily selfish. There could be a variety of reasons why someone may choose not to give to charity, and it's important to consider each individual case on its own merits rather than making broad generalizations.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man go to the doctor? Because he had a virus.
#
#
# answer:  The sentence "Why did the man go to the doctor? Because he had a virus." is a question-answer sentence, where the first part "Why did the man go to the doctor?" is a question and the second part "Because he had a virus." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the teacher go to the doctor? Because he wasn't peeling well.
#
#
# answer:  The sentence "Why did the teacher go to the doctor? Because he wasn't feeling well." is a question-answer sentence, where the first part "Why did the teacher go to the doctor?" is a question and the second part "Because he wasn't feeling well." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the driver file a police report? Because she got mugged.
#
#
# answer:  The sentence "Why did the driver file a police report? Because she got mugged." is a question-answer sentence, where the first part "Why did the driver file a police report?" is a question and the second part "Because she got mugged." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the athlete bring two pairs of pants? In case one gets dirty.
#
#
# answer:  The sentence "Why did the athlete bring two pairs of pants? In case one gets dirty." is a question-answer sentence, where the first part "Why did the athlete bring two pairs of pants?" is a question and the second part "In case one gets dirty." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man put his money in the freezer? To hide it from intruders.
#
#
# answer:  The sentence "Why did the man put his money in the freezer? To hide it from intruders." is a question-answer sentence, where the first part "Why did the man put his money in the freezer?" is a question and the second part "To hide it from intruders." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the daughter go to the seance? To talk to the other side.
#
#
# answer:  The sentence "Why did the daughter go to the seance? To talk to the other side." is a question-answer sentence, where the first part "Why did the daughter go to the seance?" is a question and the second part "To talk to the other side." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why was the cashier sent to jail? Because she held up a pair of pants.
#
#
# answer:  The sentence "Why was the cashier sent to jail? Because she held up a pair of pants." is a question-answer sentence, where the first part "Why was the cashier sent to jail?" is a question and the second part "Because she held up a pair of pants." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man cross the road? To get to the other side.
#
#
# answer:  The sentence "Why did the man cross the road? To get to the other side." is a question-answer sentence, where the first part "Why did the man cross the road?" is a question and the second part "To get to the other side." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the man go to the doctor? Because he had a bite.
#
#
# answer:  The sentence "Why did the man go to the doctor? Because he had a bite." is a question-answer sentence, where the first part "Why did the man go to the doctor?" is a question and the second part "Because he had a bite." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why did the astronaut go to outer space? To see the moon.
#
#
# answer:  The sentence "Why did the astronaut go to outer space? To see the moon." is a question-answer sentence, where the first part "Why did the astronaut go to outer space?" is a question and the second part "To see the moon." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: Why don't schoolboys fight each other? They don't have the guts.
#
#
# answer:  The sentence "Why don't schoolboys fight each other? They don't have the guts." is a question-answer sentence, where the first part "Why don't schoolboys fight each other?" is a question and the second part "They don't have the guts." is the answer to that question.
#
#
# ###### Question ######
# What kind of sentence is that: What do you call an man in a vest? A vest wearer.
#
#
# answer:  The sentence "What do you call an man in a vest? A vest wearer." is a question-answer sentence, where the first part "What do you call an man in a vest?" is a question and the second part "A vest wearer." is the answer to that question.

# %%
# that did not work 
# df.to_csv(F'{path}.csv')

# %%
for i in range(68): 
    df.iloc[i,0] = df.iloc[i,0].replace('What kind of sentence is that: ', "")
    df.iloc[i,1] = df.iloc[i,1].replace(df.iloc[i,0], "[...]")
    #df.iloc[i,1] = df.iloc[i,1].replace('"[...]"', "[...]")
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 for i in range(68):
#       2     df.iloc[i,0] = df.iloc[i,0].replace('What kind of sentence is that: ', "")
# ----> 3     df.iloc[i,1] = df.iloc[i,1].replace(df.iloc[i,0], "[...]")
#       4     #df.iloc[i,1] = df.iloc[i,1].replace('"[...]"', "[...]")
#       5 df
#
# AttributeError: 'dict' object has no attribute 'replace'

# %%
df
# Out:
#                                                prompt  \
# 0   What kind of sentence is that: Why did the sca...
# 0   What kind of sentence is that: Why did the tom...
# 0   What kind of sentence is that: Why was the mat...
# 0   What kind of sentence is that: Why don't scien...
# 0   What kind of sentence is that: Why did the coo...
# ..                                                ...
# 0   What kind of sentence is that: Why was the com...
# 0   What kind of sentence is that: Why was the stu...
# 0   What kind of sentence is that: Why was the stu...
# 0   What kind of sentence is that: Why did the tea...
# 0   What kind of sentence is that: Why don't oyste...
#
#                                              response
# 0   {'message': 'The sentence "Why did the scarecr...
# 0   {'message': 'The sentence "Why did the tomato ...
# 0   {'message': 'The sentence "Why was the math bo...
# 0   {'message': 'The sentence "Why don't scientist...
# 0   {'message': 'The sentence "Why did the cookie ...
# ..                                                ...
# 0   {'message': 'The sentence "Why was the compute...
# 0   {'message': 'The sentence "Why was the student...
# 0   {'message': 'The sentence "Why was the student...
# 0   {'message': 'The sentence "Why did the teacher...
# 0   {'message': 'The first sentence, "Why don't oy...
#
# [74 rows x 2 columns]

# %%
for i in range(df.shape[0]):
    print('####')
    print(df.iloc[i,0])
    print(df.iloc[i,1])
# Out:
# ####
# What kind of sentence is that: Why did the scarecrow win an award? Because he was outstanding in his field.
# {'message': 'The sentence "Why did the scarecrow win an award? Because he was outstanding in his field." is a joke or a pun in the form of a question-answer format. The answer "Because he was outstanding in his field." is a play on words as "outstanding" can mean both "excellent" and "standing outside". The joke refers to the fact that the scarecrow is a figure often made to stand in fields to scare away birds.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why did the tomato turn red? Because it saw the salad dressing.
# {'message': 'The sentence "Why did the tomato turn red? Because it saw the salad dressing." is also a joke or a pun. The answer "Because it saw the salad dressing." is a play on words, as "saw" can mean both "observed" and "cut", and the joke is based on the idea that the tomato, being a type of fruit, turned red due to the embarrassment it felt when it saw the salad dressing. This joke is an example of a type of humor known as a "groaner" because the punchline is predictable and often elicits a groan from the audience.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why was the math book sad? Because it had too many problems.
# {'message': 'The sentence "Why was the math book sad? Because it had too many problems." is another joke or pun. The answer "Because it had too many problems." is a play on words, as "problems" can mean both mathematical problems and difficulties. The joke is based on the idea that the math book is unhappy because it contains too many challenging mathematical problems for the reader to solve. This type of joke is a common example of word play and is often used to lighten up a conversation or bring a smile to someone\'s face.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why don't scientists trust atoms? Because they make up everything.
# {'message': 'The sentence "Why don\'t scientists trust atoms? Because they make up everything." is a joke or a pun. The answer "Because they make up everything." is a play on words, as "make up" can mean both "compose" and "fabricate". The joke is based on the idea that atoms are the basic building blocks of matter, and that scientists don\'t trust them because everything is made up of atoms and they can be used to explain or describe everything. The joke is a lighthearted take on the importance of atoms in science and the vastness of their applications in explaining the natural world.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why did the cookie go to the doctor? Because it was feeling crumbly.
# {'message': 'The sentence "Why did the cookie go to the doctor? Because it was feeling crumbly." is a joke or a pun. The answer "Because it was feeling crumbly." is a play on words, as "crumbly" can mean both "falling apart" and "having crumbs". The joke is based on the idea that the cookie was in a state of disrepair, either physically or emotionally, and needed to see a doctor. This type of joke is often used to bring a smile to someone\'s face and to add some lighthearted humor to a conversation.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why couldn't the bicycle stand up by itself? Because it was two-tired.
# {'message': 'The sentence "Why couldn\'t the bicycle stand up by itself? Because it was two-tired." is a joke or a pun. The answer "Because it was two-tired." is a play on words, as "two-tired" sounds like "too tired". The joke is based on the idea that the bicycle is exhausted and unable to stand on its own because it has two tires. This type of joke is often used to bring a smile to someone\'s face and to add some lighthearted humor to a conversation.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why did the frog call his insurance company? He had a jump in his car.
# {'message': 'The sentence "Why did the frog call his insurance company? He had a jump in his car." is a joke or a pun. The answer "He had a jump in his car." is a play on words, as "jump" can mean both a sudden movement and a boost of electrical energy to start a car engine. The joke is based on the idea that the frog had some kind of problem with his car and needed to call his insurance company for assistance. This type of joke is often used to bring a smile to someone\'s face and to add some lighthearted humor to a conversation.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why did the chicken cross the playground? To get to the other slide.
# {'message': 'The sentence "Why did the chicken cross the playground? To get to the other slide." is a joke or a pun. The answer "To get to the other slide." is a play on words, as it refers to the children\'s playground activity of sliding down a slide. The joke is based on the idea that the chicken is crossing the playground to reach the other slide, implying that the chicken is a playful or adventurous animal. This type of joke is often used to bring a smile to someone\'s face and to add some lighthearted humor to a conversation.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why was the computer cold? Because it left its Windows open.
# {'message': 'The sentence "Why did the chicken cross the playground? To get to the other slide." is a joke or a pun. The answer "To get to the other slide." is a play on words, as it refers to the children\'s playground activity of sliding down a slide. The joke is based on the idea that the chicken is crossing the playground to reach the other slide, implying that the chicken is a playful or adventurous animal. This type of joke is often used to bring a smile to someone\'s face and to add some lighthearted humor to a conversation.\n\n', 'conversation_id': 'b5168820-e630-47af-b3d9-3902a5583ae8'}
# ####
# What kind of sentence is that: Why don't oysters give to charity? Because they're shellfish.
# {'message': 'That sentence is a joke in the form of a pun. The word "shellfish" is a play on the word "selfish," suggesting that the reason oysters do not give to charity is because they are considered greedy or ungenerous.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a virus.
# {'message': 'That sentence is a joke in the form of a pun. The word "virus" is a play on the word "virus," which is a term used to describe malicious software that can infect a computer system and cause problems. The joke is that the computer went to the doctor because it was experiencing issues that were caused by a "virus."\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the banana go to the doctor? Because it wasn't peeling well.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "wasn\'t peeling well" is a play on the word "feeling," implying that the banana was experiencing some kind of health issue. The joke is that the banana went to the doctor because it was having trouble peeling, as if it were a human experiencing a physical ailment.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the coffee file a police report? Because it got mugged.
# {'message': 'That sentence is a joke in the form of a pun. The word "mugged" is a play on the word "mug," which is a term used to describe a cup or container used to hold hot beverages such as coffee. The joke is that the coffee filed a police report because it was "mugged," or taken out of its container, implying that it was stolen or taken without permission.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the golfer bring two pairs of pants? In case he got a hole in one.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "got a hole in one" is a play on the golfing term "hole in one," which refers to a shot that goes directly into the hole on a golf course. The joke is that the golfer brought two pairs of pants because he was worried about getting a "hole in one," implying that he might accidentally rip or tear his pants, which is why he brought a backup pair.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the man put his money in the freezer? He wanted cold hard cash.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "cold hard cash" is a play on words, combining the idea of money that is "hard" or tangible with the idea of something being "cold," as in stored in a refrigerator or freezer. The joke is that the man put his money in the freezer because he wanted "cold hard cash," implying that he wanted his money to be both tangible and well-preserved.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why don't seagulls fly over the bay? Because then they'd be bagels.
# {'message': 'That sentence is a joke in the form of a pun. The word "bagels" is a play on the words "bay" and "gulls," suggesting that if seagulls flew over the bay, they would be "bay-gulls," or "bagels." The joke is that the seagulls don\'t fly over the bay because they would become "bagels," which is an absurd idea.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the chicken go to the seance? To talk to the other side.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "to talk to the other side" is a play on the idea of a seance, which is a gathering where people attempt to communicate with spirits or entities from beyond the physical world. The joke is that the chicken went to the seance "to talk to the other side," implying that it wanted to communicate with the afterlife, even though chickens are a type of animal and not typically thought of as having the ability to communicate with the spirit world.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why was the belt sent to jail? Because it held up a pair of pants.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "held up a pair of pants" is a play on the phrase "held up," which is another way of saying "robbed" or "stole." The joke is that the belt was sent to jail because it "held up a pair of pants," implying that it committed a crime by supporting the pants and keeping them up.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the chicken cross the road? To get to the other side.
# {'message': 'That sentence is a classic joke in the form of a riddle. The punchline, "to get to the other side," is a play on the idea that the answer to the riddle is unexpected or absurd. The joke is that the question is a set-up for a seemingly straightforward answer, but the answer is not what one might initially expect, making the joke amusing or surprising.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a byte.
# {'message': 'That sentence is a joke in the form of a pun. The word "byte" is a play on the words "bite" and "byte," which is a unit of digital information used in computing. The joke is that the computer went to the doctor because it had a "byte," implying that it was suffering from a small amount of digital information, which is a humorous idea.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the cow go to outer space? To see the moooon.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "see the moooon" is a play on the word "moon," with "moo" being the sound that a cow makes. The joke is that the cow went to outer space to "see the moooon," implying that it wanted to observe a celestial object that is shaped like a crescent and makes a "moo" sound, which is an absurd idea.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the man put his money in the blender? He wanted to make liquid assets.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "liquid assets" is a play on words, combining the idea of assets that are easily convertible into cash with the idea of something being "liquid," as in a fluid or smooth consistency. The joke is that the man put his money in the blender because he wanted to make "liquid assets," implying that he wanted to convert his money into a fluid or smooth consistency, which is a humorous idea.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why don't skeletons fight each other? They don't have the guts.
# {'message': 'That sentence is a joke in the form of a pun. The phrase "don\'t have the guts" is a play on words, combining the idea of bravery or fortitude with the idea of the internal organs located in the abdominal cavity of a human or animal. The joke is that skeletons don\'t fight each other because they "don\'t have the guts," implying that they lack the internal organs necessary for bravery or fortitude, which is a humorous idea.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: What do you call an alligator in a vest? An investigator.
# {'message': 'That sentence is a joke in the form of a pun. The word "investigator" is a play on words, combining the idea of a person who investigates or examines something with the word "investigator," which is someone who investigates a crime or a matter of public concern. The joke is that an alligator wearing a vest is called an "investigator," implying that it is a detective or a private eye, which is a humorous idea.\n\n', 'conversation_id': '973e9161-5a50-4030-ba99-3385d4cdae2b'}
# ####
# What kind of sentence is that: Why did the scarecrow win an award? Because he did very good work.
# {'message': 'The sentence "Why did the scarecrow win an award? Because he did very good work." is an example of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the scarecrow win an award?" is a question and the second part "Because he did very good work." is the answer.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the tomato turn red? Because it had a lot sun recently.
# {'message': 'The sentence "Why did the tomato turn red? Because it had a lot sun recently." is also an example of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the tomato turn red?" is a question, and the second part "Because it had a lot sun recently." is the answer.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why was the novel sad? Because it had too many problems.
# {'message': 'The sentence "Why was the novel sad? Because it had too many problems." is also an example of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why was the novel sad?" is a question, and the second part "Because it had too many problems." is the answer.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why don't scientists trust atoms? Because they lied before.
# {'message': 'The sentence "Why don\'t scientists trust atoms? Because they made up everything." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why don\'t scientists trust atoms?" is a question, and the second part "Because they made up everything." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the cookie go to the doctor? Because it was feeling unwell.
# {'message': 'The sentence "Why did the cookie go to the doctor? Because it was feeling unwell." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the cookie go to the doctor?" is a question, and the second part "Because it was feeling unwell." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why couldn't the bicycle stand up by itself? Because it didn't have racks
# {'message': 'The sentence "Why couldn\'t the bicycle stand up by itself? Because it didn\'t have racks." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why couldn\'t the bicycle stand up by itself?" is a question, and the second part "Because it didn\'t have racks." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the frog call his insurance company? He had a scratch in his car.
# {'message': 'The sentence "Why did the frog call his insurance company? He had a scratch in his car." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the frog call his insurance company?" is a question, and the second part "He had a scratch in his car." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why was the computer cold? Because the was broken.
# {'message': 'The sentence "Why was the computer cold? Because it was broken." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why was the computer cold?" is a question, and the second part "Because it was broken." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the hipster burn his tongue? He drank too hot coffee.
# {'message': 'The sentence "Why did the hipster burn his tongue? He drank too hot coffee." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the hipster burn his tongue?" is a question, and the second part "He drank too hot coffee." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why don't oysters give to charity? Because they cannot walk.
# {'message': 'The sentence "Why don\'t oysters give to charity? Because they can\'t walk." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why don\'t oysters give to charity?" is a question, and the second part "Because they can\'t walk." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it was sick.
# {'message': 'The sentence "Why did the computer go to the doctor? Because it was sick." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the computer go to the doctor?" is a question, and the second part "Because it was sick." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the banana go to the doctor? Because it was sick.
# {'message': 'The sentence "Why did the computer go to the doctor? Because it was sick." is an example of a joke in the form of a question-answer sentence or a type of interrogative-declarative sentence. The first part "Why did the computer go to the doctor?" is a question, and the second part "Because it was sick." is the punchline.\n\n', 'conversation_id': '6b6fb8db-11ea-4533-99ad-b62ee20b3ce2'}
# ####
# What kind of sentence is that: Why did the swimmer bring two pairs of pants? In case he got a hole in one.
# {'message': 'The sentence "Why did the swimmer bring two pairs of pants? In case he got a hole in one." is a joke or a pun. The punchline "In case he got a hole in one" is a play on words, as "hole in one" is a term used in golf to describe when a golfer sinks a shot into the hole in one stroke, and in this sentence, it is being used as if the swimmer might get a hole in his pants.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why did the man put his money in the piggy bank? To save some cash.
# {'message': 'The sentence "Why did the man put his money in the piggy bank? To save some cash." is a joke or a pun. The punchline "To save some cash" is a play on words, as "save some cash" means to keep or accumulate money, and in this sentence, it is being used as if the man is saving the actual cash by putting it into the piggy bank.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why don't seagulls fly over the bay? Because then are mostly living in ports.
# {'message': 'The sentence "Why don\'t seagulls fly over the bay? Because then are mostly living in ports." is a joke or a pun. The punchline "Because then are mostly living in ports" is a play on words, as "port" can mean both a place where ships dock and also a direction or orientation, and in this sentence, it is being used to suggest that the seagulls are not flying over the bay because they are oriented towards the ports where they live.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why was the belt sent to jail? Because it stole a pair of pants.
# {'message': 'The sentence "Why was the belt sent to jail? Because it stole a pair of pants." is a joke or a pun. The punchline "Because it stole a pair of pants" is a play on words, as "stole" can mean both to take something without permission and also to support or hold up, and in this sentence, it is being used to suggest that the belt was sent to jail because it took the pants without permission.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it wasn't feeling well.
# {'message': 'The sentence "Why did the computer go to the doctor? Because it wasn\'t feeling well." is a joke or a pun. The punchline "Because it wasn\'t feeling well" is a play on words, as "feeling well" is a phrase commonly used to describe good health in humans, and in this sentence, it is being used to suggest that the computer, which is a machine, was not functioning properly or was experiencing some kind of technical problem.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why did the chicken go to outer space? To see the moon.
# {'message': 'The sentence "Why did the chicken go to outer space? To see the moon." is a joke or a pun. The punchline "To see the moon" is a play on words, as "to see the moon" is a phrase that can be taken literally to mean observing the moon from a distance, and in this sentence, it is being used to suggest that the chicken went to outer space for this reason, which is absurd.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why did the man put bananas in the blender? He wanted to make a smoothie.
# {'message': 'The sentence "Why did the man put bananas in the blender? He wanted to make a smoothie." is a straightforward statement and not a joke or a pun. The man put the bananas in the blender in order to make a smoothie, which is a popular drink made from blending fruit and sometimes other ingredients.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why don't skeletons fight each other? They are quite peaceful.
# {'message': 'The sentence "Why don\'t skeletons fight each other? They are quite peaceful." is a joke or a pun. The punchline "They are quite peaceful" is a play on words, as "peaceful" is a word used to describe someone or something that is calm and non-violent, and in this sentence, it is being used to suggest that skeletons, which are commonly depicted as scary or frightening, are actually quite peaceful and do not fight with each other.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why don't skeletons fight each other? They are dead already.
# {'message': 'The sentence "Why don\'t skeletons fight each other? They are dead already." is a joke or a pun. The punchline "They are dead already" is a play on words, as "dead" is a term used to describe someone or something that is no longer alive, and in this sentence, it is being used to suggest that skeletons, which are often depicted as being made of bones, do not fight with each other because they are already dead.\n\n', 'conversation_id': '810f2f9c-3a93-40e4-9991-7f697cd79aaf'}
# ####
# What kind of sentence is that: Why did the boy win an award? Because he did very good work.
# {'message': 'The sentence "Why did the boy win an award? Because he did very good work." is an example of a question-answer sentence. The first part "Why did the boy win an award?" is a question, and the second part "Because he did very good work." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the man turn red? Because he saw the neighbour dressing.
# {'message': 'The sentence "Why did the man turn red? Because he saw the neighbor dressing." is also an example of a question-answer sentence, where the first part "Why did the man turn red?" is a question and the second part "Because he saw the neighbor dressing." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why was the child sad? Because it had too many problems.
# {'message': 'The sentence "Why was the child sad? Because it had too many problems." is also a question-answer sentence, where the first part "Why was the child sad?" is a question and the second part "Because it had too many problems." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why don't scientists trust journalists? Because they make up everything.
# {'message': 'The sentence "Why don\'t scientists trust journalists? Because they make up everything." is also a question-answer sentence, where the first part "Why don\'t scientists trust journalists?" is a question and the second part "Because they make up everything." is the answer to that question.\n\nIt\'s important to note that the answer given in this sentence is a generalization and not necessarily accurate. Many journalists work hard to report accurately and responsibly, and not all scientists distrust journalists. It\'s important to be mindful of making broad generalizations, as they can perpetuate harmful stereotypes and misunderstandings.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the woman go to the doctor? Because it was feeling crumbly.
# {'message': 'The sentence "Why did the woman go to the doctor? Because she was feeling crumbly." is a question-answer sentence, where the first part "Why did the woman go to the doctor?" is a question and the second part "Because she was feeling crumbly." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why couldn't the kid stand up by itself? Because it was too tired.
# {'message': 'The sentence "Why couldn\'t the kid stand up by itself? Because it was too tired." is a question-answer sentence, where the first part "Why couldn\'t the kid stand up by itself?" is a question and the second part "Because it was too tired." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the driver call his insurance company? He had a jump in his car.
# {'message': 'The sentence "Why did the driver call his insurance company? He had a jump in his car." is a question-answer sentence, where the first part "Why did the driver call his insurance company?" is a question and the second part "He had a jump in his car." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the cild cross the playground? To get to the slide.
# {'message': 'The sentence "Why did the child cross the playground? To get to the slide." is a question-answer sentence, where the first part "Why did the child cross the playground?" is a question and the second part "To get to the slide." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why was the woman cold? Because she left its Windows open.
# {'message': 'The sentence "Why was the woman cold? Because she left her windows open." is a question-answer sentence, where the first part "Why was the woman cold?" is a question and the second part "Because she left her windows open." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the coworker burn his tongue? He drank his coffee before it was cool.
# {'message': 'The sentence "Why did the coworker burn his tongue? He drank his coffee before it was cool." is a question-answer sentence, where the first part "Why did the coworker burn his tongue?" is a question and the second part "He drank his coffee before it was cool." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why don't millionaire give to charity? Because he is selfish.
# {'message': 'The sentence "Why don\'t millionaires give to charity? Because they are selfish." is a question-answer sentence, where the first part "Why don\'t millionaires give to charity?" is a question and the second part "Because they are selfish." is the answer to that question.\n\nIt\'s important to note that this answer is a generalization and not necessarily accurate. Many millionaires do give to charity, and not all who do not give to charity are necessarily selfish. There could be a variety of reasons why someone may choose not to give to charity, and it\'s important to consider each individual case on its own merits rather than making broad generalizations.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the man go to the doctor? Because he had a virus.
# {'message': 'The sentence "Why did the man go to the doctor? Because he had a virus." is a question-answer sentence, where the first part "Why did the man go to the doctor?" is a question and the second part "Because he had a virus." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the teacher go to the doctor? Because he wasn't peeling well.
# {'message': 'The sentence "Why did the teacher go to the doctor? Because he wasn\'t feeling well." is a question-answer sentence, where the first part "Why did the teacher go to the doctor?" is a question and the second part "Because he wasn\'t feeling well." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the driver file a police report? Because she got mugged.
# {'message': 'The sentence "Why did the driver file a police report? Because she got mugged." is a question-answer sentence, where the first part "Why did the driver file a police report?" is a question and the second part "Because she got mugged." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the athlete bring two pairs of pants? In case one gets dirty.
# {'message': 'The sentence "Why did the athlete bring two pairs of pants? In case one gets dirty." is a question-answer sentence, where the first part "Why did the athlete bring two pairs of pants?" is a question and the second part "In case one gets dirty." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the man put his money in the freezer? To hide it from intruders.
# {'message': 'The sentence "Why did the man put his money in the freezer? To hide it from intruders." is a question-answer sentence, where the first part "Why did the man put his money in the freezer?" is a question and the second part "To hide it from intruders." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the daughter go to the seance? To talk to the other side.
# {'message': 'The sentence "Why did the daughter go to the seance? To talk to the other side." is a question-answer sentence, where the first part "Why did the daughter go to the seance?" is a question and the second part "To talk to the other side." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why was the cashier sent to jail? Because she held up a pair of pants.
# {'message': 'The sentence "Why was the cashier sent to jail? Because she held up a pair of pants." is a question-answer sentence, where the first part "Why was the cashier sent to jail?" is a question and the second part "Because she held up a pair of pants." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the man cross the road? To get to the other side.
# {'message': 'The sentence "Why did the man cross the road? To get to the other side." is a question-answer sentence, where the first part "Why did the man cross the road?" is a question and the second part "To get to the other side." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the man go to the doctor? Because he had a bite.
# {'message': 'The sentence "Why did the man go to the doctor? Because he had a bite." is a question-answer sentence, where the first part "Why did the man go to the doctor?" is a question and the second part "Because he had a bite." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why did the astronaut go to outer space? To see the moon.
# {'message': 'The sentence "Why did the astronaut go to outer space? To see the moon." is a question-answer sentence, where the first part "Why did the astronaut go to outer space?" is a question and the second part "To see the moon." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why don't schoolboys fight each other? They don't have the guts.
# {'message': 'The sentence "Why don\'t schoolboys fight each other? They don\'t have the guts." is a question-answer sentence, where the first part "Why don\'t schoolboys fight each other?" is a question and the second part "They don\'t have the guts." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: What do you call an man in a vest? A vest wearer.
# {'message': 'The sentence "What do you call an man in a vest? A vest wearer." is a question-answer sentence, where the first part "What do you call an man in a vest?" is a question and the second part "A vest wearer." is the answer to that question.\n\n', 'conversation_id': '9e0b9022-a2d8-4663-8cfa-cd7ff15453c6'}
# ####
# What kind of sentence is that: Why was the computer cold? Because the heater was broken.
# {'message': 'The sentence "Why was the computer cold? Because the heater was broken" is a complex sentence. It consists of two clauses, an independent clause "Why was the computer cold?" and a dependent clause "Because the heater was broken." The independent clause can stand alone as a complete sentence, but the dependent clause cannot stand alone and relies on the independent clause for meaning. The two clauses are connected with a subordinating conjunction "because."\n\n', 'conversation_id': '6f27b41e-1653-46ba-bb21-4f3046b399db'}
# ####
# What kind of sentence is that: Why was the computer cold? Because it was winter.
# {'message': 'The sentence "Why was the computer cold? Because it was winter" is also a complex sentence. It consists of two clauses, an independent clause "Why was the computer cold?" and a dependent clause "Because it was winter." The independent clause can stand alone as a complete sentence, but the dependent clause cannot stand alone and relies on the independent clause for meaning. The two clauses are connected with a subordinating conjunction "because."\n\n', 'conversation_id': '6f27b41e-1653-46ba-bb21-4f3046b399db'}
# ####
# What kind of sentence is that: Why was the student cold? Because the heater was broken.
# {'message': 'The sentence "Why was the student cold? Because the heater was broken" is a complex sentence. It consists of two clauses, an independent clause "Why was the student cold?" and a dependent clause "Because the heater was broken." The independent clause can stand alone as a complete sentence, but the dependent clause cannot stand alone and relies on the independent clause for meaning. The two clauses are connected with a subordinating conjunction "because."\n\n', 'conversation_id': '6f27b41e-1653-46ba-bb21-4f3046b399db'}
# ####
# What kind of sentence is that: Why was the student cold? Because it was winter.
# {'message': 'The sentence "Why was the student cold? Because it was winter" is also a complex sentence. It consists of two clauses, an independent clause "Why was the student cold?" and a dependent clause "Because it was winter." The independent clause can stand alone as a complete sentence, but the dependent clause cannot stand alone and relies on the independent clause for meaning. The two clauses are connected with a subordinating conjunction "because."\n\n', 'conversation_id': '6f27b41e-1653-46ba-bb21-4f3046b399db'}
# ####
# What kind of sentence is that: Why did the teacher go to the doctor? Because he wasn't peeling well.
# {'message': 'The sentence "Why did the teacher go to the doctor? Because he wasn\'t feeling well." is a play on words or a pun, as it uses a double meaning of the word "peeling" to create a humorous effect. Grammatically, the sentence is a complex sentence, consisting of two clauses: the first clause is a question ("Why did the teacher go to the doctor?") and the second clause provides the answer ("Because he wasn\'t feeling well.").\n\n', 'conversation_id': '5a81c1b1-38c6-42a6-881e-88b1291eaa6a'}
# ####
# What kind of sentence is that: Why don't oysters give to charity? Because they have no money.
# {'message': 'The first sentence, "Why don\'t oysters give to charity?" is an interrogative sentence because it is asking a question.\n\nThe second sentence, "Because they have no money," is a declarative sentence because it is making a statement. Specifically, it is providing an explanation or reason for the lack of charitable giving by oysters.\n\n', 'conversation_id': '0ef3e4f3-3527-45ed-a575-9db09dbdab22'}

# %%
import pandas as pd

#path = 'joke_detection'
#path = 'joke_detection_allshuffle'
path = 'joke_detection_onesense'
df = pd.read_pickle(path)
print(df.shape)
df.shape

for i in range(df.shape[0] ): 
    df.iloc[i,1] = df.iloc[i,1]['message']
    df.iloc[i,0] = df.iloc[i,0].replace('What kind of sentence is that: ', "")
    df.iloc[i,1] = df.iloc[i,1].replace(df.iloc[i,0], "[...]")
    #df.iloc[i,1] = df.iloc[i,1].replace('"[...]"', "[...]")

for i in range(df.shape[0] ):
    print('####')
    print(df.iloc[i,0])
    print(df.iloc[i,1])

    
df
# Out:
# (25, 2)
# ####
# The scarecrow won an award because he was outstanding in his field.
# This sentence is an example of a pun, a play on words. The phrase "outstanding in his field" is a play on the phrase "outstanding" and the literal meaning of being "in his field," as in a field of crops. The pun creates a humorous effect by using a phrase in a way that gives it a second, often humorous meaning.
#
#
# ####
# The tomato turned red because it saw the salad dressing.
# The sentence "The tomato turned red because it saw the salad dressing" is an example of personification, where human-like qualities are attributed to a non-human entity or object. In this case, the tomato is given the human-like ability to "see" and respond to the sight of salad dressing by "turning red," when in reality, the tomato's color changes due to the ripening process. Personification is a common literary device used to make descriptions more engaging, interesting, and relatable to the reader.
#
#
# ####
# The math book was sad because it had too many problems.
# The sentence "The math book was sad because it had too many problems" is an example of personification, where human-like qualities are attributed to a non-human entity or object. In this case, the math book is given the human-like emotion of being "sad," when in reality, the book is an inanimate object and cannot feel emotions. Personification is a common literary device used to make descriptions more engaging, interesting, and relatable to the reader.
#
#
# ####
# Scientists don't trust atoms because they make up everything.
# The sentence "Scientists don't trust atoms because they make up everything" is an example of a humorous statement, which uses a play on words to create a joke. The sentence relies on the multiple meanings of the phrase "make up," which can refer to atoms being the basic building blocks of matter, but can also mean to fabricate or lie. The sentence is not intended to be taken literally, but rather to create a humorous effect by subverting the reader's expectations with a clever play on words.
#
#
# ####
# The cookie went to the doctor because it was feeling crumbly.
# The sentence "The cookie went to the doctor because it was feeling crumbly" is an example of personification, where human-like qualities are attributed to a non-human entity or object. In this case, the cookie is given the ability to "feel" and respond to its physical condition of being "crumbly," when in reality, the cookie is an inanimate object and cannot feel anything. Personification is a common literary device used to make descriptions more engaging, interesting, and relatable to the reader. The sentence is also an example of a playful, humorous statement that uses wordplay to create a lighthearted effect.
#
#
# ####
# The bicycle couldn't stand up by itself because it was two-tired.
# The sentence "The bicycle couldn't stand up by itself because it was two-tired" is an example of a pun, a play on words. The sentence relies on the double meaning of the word "tired," which can refer to the condition of being exhausted, but in this case, it is a pun on the word "tire," which is a component of a bicycle wheel. The sentence is not intended to be taken literally but rather to create a humorous effect by using a word in a way that gives it a second, often humorous meaning. Puns are a common form of wordplay used to create humor in writing and speech.
#
#
# ####
# The frog called his insurance company because he had a jump in his car.
# The sentence "The frog called his insurance company because he had a jump in his car" is an example of a pun, a play on words. The sentence relies on the double meaning of the word "jump," which can refer to a sudden upward movement or to starting a car with jumper cables. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a word in a way that gives it a second, often humorous meaning. Puns are a common form of wordplay used to create humor in writing and speech. The sentence is also an example of personification, where human-like qualities are attributed to a non-human entity or object. In this case, the frog is given the ability to operate a car, which is a human activity.
#
#
# ####
# The chicken crossed the playground to get to the other slide.
# The sentence "The chicken crossed the playground to get to the other slide" is an example of a humorous statement that uses wordplay to create a lighthearted effect. The sentence is a twist on the familiar phrase "The chicken crossed the road," which is often used as the setup for a joke. In this case, the sentence subverts the reader's expectations by revealing that the chicken's true destination is not on the other side of the road but on the other side of the playground, at a different slide. The sentence is not intended to be taken literally but rather to create a playful, whimsical effect by using a familiar phrase in an unexpected way.
#
#
# ####
# The computer was cold because it left its Windows open.
# The sentence "The computer was cold because it left its Windows open" is an example of a pun, a play on words. The sentence relies on the multiple meanings of the word "Windows," which can refer to the Microsoft operating system, but can also refer to the physical windows on a building. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a word in a way that gives it a second, often humorous meaning. Puns are a common form of wordplay used to create humor in writing and speech. The sentence is also an example of personification, where human-like qualities are attributed to a non-human entity or object. In this case, the computer is given the ability to feel "cold" as a result of its windows being left open, when in reality, the computer is an inanimate object and cannot feel anything.
#
#
# ####
# The hipster burned his tongue because he drank his coffee before it was cool.
# The sentence "The hipster burned his tongue because he drank his coffee before it was cool" is an example of a pun, a play on words. The sentence relies on the multiple meanings of the word "cool," which can mean at a low temperature, but can also mean fashionable or trendy. In this case, the sentence is a humorous twist on the phrase "cool down," where the reader expects the sentence to reference the temperature of the coffee. However, the sentence subverts the reader's expectations by using "cool" to reference the hipster's desire to be ahead of the trend. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a word in a way that gives it a second, often humorous meaning. Puns are a common form of wordplay used to create humor in writing and speech.
#
#
# ####
# Oysters don't give to charity because they're shellfish.
# The sentence "Oysters don't give to charity because they're shellfish" is an example of a pun, a play on words. The sentence relies on the double meaning of the word "shellfish," which can refer to a type of seafood, but can also mean a person who is selfish or self-centered. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a word in a way that gives it a second, often humorous meaning. Puns are a common form of wordplay used to create humor in writing and speech.
#
#
# ####
# The computer went to the doctor because it had a virus.
# The sentence "The computer went to the doctor because it had a virus" is an example of personification, a literary device in which human-like qualities are attributed to a non-human entity or object. In this case, the computer is given the human-like ability to seek medical attention and have an illness, which in reality is a computer virus. The sentence is not intended to be taken literally, but rather to create a playful effect by using personification to convey the idea that the computer has a problem that needs to be fixed. This type of sentence is often used for humorous effect or to make a topic more relatable by anthropomorphizing it.
#
#
# ####
# The banana went to the doctor because it wasn't peeling well.
# The sentence "The banana went to the doctor because it wasn't peeling well" is an example of personification, a literary device in which human-like qualities are attributed to a non-human entity or object. In this case, the banana is given the human-like ability to seek medical attention and have an illness, which in reality is a metaphor for the fact that the banana is difficult to peel. The sentence is not intended to be taken literally, but rather to create a playful effect by using personification to convey the idea that the banana has a problem that needs to be addressed. This type of sentence is often used for humorous effect or to make a topic more relatable by anthropomorphizing it.
#
#
# ####
# The coffee filed a police report because it got mugged.
# The sentence "The coffee filed a police report because it got mugged" is an example of personification, a literary device in which human-like qualities are attributed to a non-human entity or object. In this case, the coffee is given the human-like ability to file a police report and have been "mugged," which is a metaphor for having its contents stolen or spilled. The sentence is not intended to be taken literally, but rather to create a playful effect by using personification to convey the idea that the coffee has experienced a negative event that would typically happen to a person. This type of sentence is often used for humorous effect or to make a topic more relatable by anthropomorphizing it.
#
#
# ####
# The golfer brings two pairs of pants in case he got a hole in one.
# The sentence "The golfer brings two pairs of pants in case he got a hole in one" is an example of a joke or a humorous statement. The sentence plays with the double meaning of "hole in one," which in golf refers to hitting the ball directly into the cup with one stroke, but in this sentence, refers to tearing a hole in the golfer's pants. The sentence is not intended to be taken literally, but rather to create a humorous effect by using wordplay to convey the idea that the golfer wants to be prepared for any scenario. This type of sentence is often used in jokes, puns, and other forms of humor.
#
#
# ####
# The man put his money in the freezer because he wanted cold hard cash.
# The sentence "The man put his money in the freezer because he wanted cold hard cash" is an example of a pun, a play on words. The sentence relies on the double meaning of the phrase "cold hard cash," which can mean physical currency that is cold to the touch, but can also mean money that is difficult to obtain or acquire. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a phrase in a way that gives it a second, often humorous meaning. Puns are a common form of wordplay used to create humor in writing and speech.
#
#
# ####
# Seagulls don't fly over the bay because then they'd be bagels.
# The sentence "Seagulls don't fly over the bay because then they'd be bagels" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. In this case, the sentence plays on the similarity in sound between the words "bay" and "bagel" to create a humorous effect. The sentence is not intended to be taken literally, but rather to create a humorous effect by using language in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# The chicken went to the seance to talk to the other side.
# The sentence "The chicken went to the seance to talk to the other side" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. The sentence plays on the ambiguity of the phrase "the other side," which can mean the afterlife in a supernatural sense, but can also mean the other end of a physical space or location. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a phrase in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# The belt was sent to jail because it held up a pair of pants.
# The sentence "The belt was sent to jail because it held up a pair of pants" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. The sentence plays on the different meanings of "held up", which can mean to support, as in holding up pants, or to rob or steal, as in a hold-up or robbery. The sentence is not intended to be taken literally, but rather to create a humorous effect by using a phrase in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# The chicken crossed the road to get to the other side.
# The sentence "The chicken crossed the road to get to the other side" is an example of a classic joke that relies on the listener's expectation of a punchline or surprise ending. While the sentence is grammatically a simple statement, it is commonly told as a setup to a joke, with the listener anticipating a clever twist or surprise ending that ultimately does not come. The humor of the sentence comes from the contrast between the simple, straightforward statement and the expectation of a clever or humorous twist. The sentence has become a popular cultural reference and a classic example of a joke.
#
#
# ####
# The computer went to the doctor because it had a byte.
# The sentence "The computer went to the doctor because it had a byte" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. The sentence plays on the similarity in sound between "byte" (a unit of digital information) and "bite" (a small amount of food taken into the mouth). The sentence is not intended to be taken literally, but rather to create a humorous effect by using language in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# The cow went to outer space to see the moooon.
# The sentence "The cow went to outer space to see the moooon" is an example of a play on words that uses a pun to create a humorous effect. The sentence plays on the similarity in sound between "moon" and "moo" and imagines a scenario in which a cow goes to outer space to see the celestial body that shares its name. The sentence is not intended to be taken literally, but rather to create a humorous effect by using language in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# The man put his money in the blender because he wanted to make liquid assets.
# The sentence "The man put his money in the blender because he wanted to make liquid assets" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. The sentence plays on the financial term "liquid assets," which refers to assets that can be easily converted into cash, and the literal meaning of "liquid" as a substance that can flow, such as the blended contents of a blender. The sentence is not intended to be taken literally, but rather to create a humorous effect by using language in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# Skeletons don't fight each other because they don't have the guts.
# The sentence "Skeletons don't fight each other because they don't have the guts" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. The sentence plays on the two different meanings of "guts" – it can mean both courage and internal organs. The sentence suggests that skeletons don't have the organs to fight each other and don't have the courage to do so as well. The sentence is not intended to be taken literally, but rather to create a humorous effect by using language in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#
#
# ####
# An alligator in a vest is called an investigator.
# The sentence "An alligator in a vest is called an investigator" is an example of a pun, a form of wordplay that relies on the double meaning of words or phrases. The sentence plays on the similarity of the words "alligator" and "investigator" and creates a humorous image of an alligator wearing a vest and investigating something. The sentence is not intended to be taken literally, but rather to create a humorous effect by using language in a way that gives it a second, often playful meaning. Puns are a common form of wordplay used in humor, poetry, and other forms of creative writing.
#                                               prompt  \
# 0  The scarecrow won an award because he was outs...
# 0  The tomato turned red because it saw the salad...
# 0  The math book was sad because it had too many ...
# 0  Scientists don't trust atoms because they make...
# 0  The cookie went to the doctor because it was f...
# 0  The bicycle couldn't stand up by itself becaus...
# 0  The frog called his insurance company because ...
# 0  The chicken crossed the playground to get to t...
# 0  The computer was cold because it left its Wind...
# 0  The hipster burned his tongue because he drank...
# 0  Oysters don't give to charity because they're ...
# 0  The computer went to the doctor because it had...
# 0  The banana went to the doctor because it wasn'...
# 0  The coffee filed a police report because it go...
# 0  The golfer brings two pairs of pants in case h...
# 0  The man put his money in the freezer because h...
# 0  Seagulls don't fly over the bay because then t...
# 0  The chicken went to the seance to talk to the ...
# 0  The belt was sent to jail because it held up a...
# 0  The chicken crossed the road to get to the oth...
# 0  The computer went to the doctor because it had...
# 0     The cow went to outer space to see the moooon.
# 0  The man put his money in the blender because h...
# 0  Skeletons don't fight each other because they ...
# 0  An alligator in a vest is called an investigator.
#
#                                             response
# 0  This sentence is an example of a pun, a play o...
# 0  The sentence "The tomato turned red because it...
# 0  The sentence "The math book was sad because it...
# 0  The sentence "Scientists don't trust atoms bec...
# 0  The sentence "The cookie went to the doctor be...
# 0  The sentence "The bicycle couldn't stand up by...
# 0  The sentence "The frog called his insurance co...
# 0  The sentence "The chicken crossed the playgrou...
# 0  The sentence "The computer was cold because it...
# 0  The sentence "The hipster burned his tongue be...
# 0  The sentence "Oysters don't give to charity be...
# 0  The sentence "The computer went to the doctor ...
# 0  The sentence "The banana went to the doctor be...
# 0  The sentence "The coffee filed a police report...
# 0  The sentence "The golfer brings two pairs of p...
# 0  The sentence "The man put his money in the fre...
# 0  The sentence "Seagulls don't fly over the bay ...
# 0  The sentence "The chicken went to the seance t...
# 0  The sentence "The belt was sent to jail becaus...
# 0  The sentence "The chicken crossed the road to ...
# 0  The sentence "The computer went to the doctor ...
# 0  The sentence "The cow went to outer space to s...
# 0  The sentence "The man put his money in the ble...
# 0  The sentence "Skeletons don't fight each other...
# 0  The sentence "An alligator in a vest is called...

# %%
import pandas as pd

#path = 'joke_detection'
path = 'joke_detection_allshuffle'
#path = 'joke_detection_onesense'
df = pd.read_pickle(path)
print(df.shape)
df.shape

for i in range(df.shape[0] ): 
    df.iloc[i,1] = df.iloc[i,1]['message']
    df.iloc[i,0] = df.iloc[i,0].replace('What kind of sentence is that: ', "")
    df.iloc[i,1] = df.iloc[i,1].replace(df.iloc[i,0], "[...]")
    #df.iloc[i,1] = df.iloc[i,1].replace('"[...]"', "[...]")

for i in range(df.shape[0] ):
    print('####')
    print(df.iloc[i,0])
    print(df.iloc[i,1])

    
df
# Out:
# (83, 2)
# ####
# The belt was sent to jail because it held up a pair of pants.
# The sentence is an example of a personification figure of speech, where the inanimate object (the belt) is given human-like qualities, actions, or emotions. Specifically, in this sentence, the belt is anthropomorphized as though it is capable of committing a crime and being sentenced to jail. It is a declarative sentence, expressing a statement of fact or opinion.
#
#
# ####
# Why don't schoolboys fight each other? They don't have the guts.
# The first sentence is an interrogative sentence, as it asks a question ("Why don't schoolboys fight each other?"). The second sentence is a declarative sentence, expressing a statement of fact or opinion ("They don't have the guts"). Together, the two sentences form a dialogue or exchange, where the first sentence poses a question, and the second sentence provides an answer or explanation.
#
#
# ####
# Why don't seagulls fly over the bay? Because then they'd be bagels.
# The first sentence is an interrogative sentence, as it asks a question ("Why don't seagulls fly over the bay?"). The second sentence is a declarative sentence, expressing a reason or explanation for the question asked ("Because then they'd be bagels"). Together, the two sentences form a joke or pun, where the question sets up an expectation for a serious answer, and the second sentence subverts that expectation with a humorous play on words.
#
#
# ####
# Why did the chicken cross the road? To get to the other side.
# The first sentence is an interrogative sentence, as it asks a question ("Why did the chicken cross the road?"). The second sentence is a declarative sentence, expressing an answer to the question asked ("To get to the other side"). Together, the two sentences form a classic riddle or joke, where the question sets up an expectation for a clever or unexpected answer, but the answer turns out to be a simple and straightforward explanation.
#
#
# ####
# What do you call an alligator in a vest? An investigator.
# The sentence is an example of a joke or pun. The first sentence is an interrogative sentence, as it asks a question ("What do you call an alligator in a vest?"). The second sentence is a declarative sentence, expressing a play on words and providing a humorous answer to the question asked ("An investigator"). Specifically, the sentence plays on the similarity between the word "investigator" and the pronunciation of "in-vest-igator," which is a humorous description of an alligator wearing a vest.
#
#
# ####
# Why did the computer go to the doctor? Because it had a byte.
# The first sentence is an interrogative sentence, as it asks a question ("Why did the computer go to the doctor?"). The second sentence is a declarative sentence, expressing a pun and providing a humorous answer to the question asked ("Because it had a byte"). Specifically, the sentence plays on the similarity between the word "byte" (a unit of digital information) and "bite" (a wound caused by the action of teeth). This creates a humorous image of a computer with a toothache-like problem that requires a visit to the doctor.
#
#
# ####
# Why was the cashier sent to jail? Because she held up a pair of pants.
# The first sentence is an interrogative sentence, as it asks a question ("Why was the cashier sent to jail?"). The second sentence is a declarative sentence, expressing a play on words and providing a humorous answer to the question asked ("Because she held up a pair of pants"). Specifically, the sentence plays on the multiple meanings of the phrase "held up." In one sense, it can mean to raise or elevate something, such as a pair of pants. In another sense, it can mean to rob or steal from someone, typically at gunpoint. By using this second meaning in a pun, the sentence creates a humorous image of a cashier robbing a pair of pants.
#
#
# ####
# Why don't millionaire give to charity? Because he is selfish.
# The first sentence is an interrogative sentence, as it asks a question ("Why don't millionaires give to charity?"). The second sentence is a declarative sentence, expressing an answer to the question asked ("Because he is selfish"). However, the second sentence contains a grammatical error. It uses the singular pronoun "he" to refer to millionaires in general, which is incorrect and could be considered a form of gender bias. A more accurate and inclusive sentence would be: "Because they are selfish." This sentence is still a declarative sentence, expressing an opinion or belief about why some millionaires might not donate to charity.
#
#
# ####
# Why did the cild cross the playground? To get to the slide.
# The first sentence is an interrogative sentence, as it asks a question ("Why did the child cross the playground?"). The second sentence is a declarative sentence, expressing an answer to the question asked ("To get to the slide"). Together, the two sentences form a simple joke or riddle that plays on the expectation of a complicated or unexpected answer to a question. Instead, the answer is straightforward and involves a child's typical behavior on a playground.
#
#
# ####
# Why don't seagulls fly over the bay? Because then are mostly living in ports.
# The first sentence is an interrogative sentence, as it asks a question ("Why did the child cross the playground?"). The second sentence is a declarative sentence, expressing an answer to the question asked ("To get to the slide"). Together, the two sentences form a simple joke or riddle that plays on the expectation of a complicated or unexpected answer to a question. Instead, the answer is straightforward and involves a child's typical behavior on a playground.
#
#
# ####
# Why did the man put his money in the piggy bank? To save some cash.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why did the man put his money in the piggy bank?" is an interrogative sentence, as it asks a question. The second part, "To save some cash," is a declarative sentence, as it makes a statement.
#
#
# ####
# The frog called his insurance company because he had a jump in his car.
# The given sentence is a declarative sentence, as it makes a statement. Specifically, the sentence is describing an action taken by the frog (calling his insurance company) due to a particular situation (a jump in his car).
#
#
# ####
# Why did the boy win an award? Because he did very good work.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why did the boy win an award?" is an interrogative sentence, as it asks a question. The second part, "Because he did very good work," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why did the coffee file a police report? Because it got robbed.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why did the coffee file a police report?" is an interrogative sentence, as it asks a question. The second part, "Because it got robbed," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why did the computer go to the doctor? Because it had a virus.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why did the computer go to the doctor?" is an interrogative sentence, as it asks a question. The second part, "Because it had a virus," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why did the swimmer bring two pairs of pants? In case he got a hole in one.
# The given sentence is a two-part sentence consisting of a question and a punchline. The first part, "Why did the swimmer bring two pairs of pants?" is an interrogative sentence, as it asks a question. The second part, "In case he got a hole in one," is a pun, which is a play on words that relies on a double meaning, in this case, "hole in one" can refer to both a golf term and getting a hole in one's pants. It is not a sentence type but still a grammatical and semantic construction.
#
#
# ####
# Why was the child sad? Because it had too many problems.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why was the child sad?" is an interrogative sentence, as it asks a question. The second part, "Because it had too many problems," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why did the teacher go to the doctor? Because he wasn't peeling well.
# The given sentence is a two-part sentence consisting of a question and a punchline. The first part, "Why did the teacher go to the doctor?" is an interrogative sentence, as it asks a question. The second part, "Because he wasn't peeling well," is a pun, which is a play on words that relies on a double meaning, in this case, "peeling well" sounds like "feeling well" but refers to peeling fruits or vegetables. It is not a sentence type but still a grammatical and semantic construction.
#
#
# ####
# Why was the woman cold? Because she left its Windows open.
# The given sentence contains an error in subject-verb agreement. The correct version of the sentence with the error corrected would be: "Why was the woman cold? Because she left her windows open."
#
# The first part, "Why was the woman cold?" is an interrogative sentence, as it asks a question. The second part, "Because she left her windows open," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why don't oysters give to charity? Because they're shellfish.
# The given sentence is a two-part sentence consisting of a question and a punchline. The first part, "Why don't oysters give to charity?" is an interrogative sentence, as it asks a question. The second part, "Because they're shellfish," is a pun, which is a play on words that relies on a double meaning, in this case, "shellfish" can refer to oysters and other seafood, as well as being selfish or not sharing. It is not a sentence type but still a grammatical and semantic construction.
#
#
# ####
# Why was the computer cold? Because the heater was broken.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why was the computer cold?" is an interrogative sentence, as it asks a question. The second part, "Because the heater was broken," is a declarative sentence, as it makes a statement.
#
#
# ####
# The math book was sad because it had too many problems.
# The given sentence is a declarative sentence, as it makes a statement. Specifically, the sentence is describing the emotion of the math book (sadness) and the reason for it (having too many problems).
#
#
# ####
# Why don't seagulls fly over the bay? Because then are mostly living in ports.
# The given sentence contains a grammatical error. A corrected version of the sentence would be: "Why don't seagulls fly over the bay? Because they mostly live in ports."
#
# The first part, "Why don't seagulls fly over the bay?" is an interrogative sentence, as it asks a question. The second part, "Because they mostly live in ports," is a declarative sentence, as it makes a statement.
#
#
# ####
# The chicken crossed the road to get to the other side.
# The given sentence is a declarative sentence, as it makes a statement. Specifically, the sentence is describing an action taken by the chicken (crossing the road) and the reason for it (to get to the other side). This sentence is also a classic example of a joke or riddle answer.
#
#
# ####
# Why did the kid cross the playground? To get to the slide.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why did the kid cross the playground?" is an interrogative sentence, as it asks a question. The second part, "To get to the slide," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why don't oysters give to charity? Because they have no money.
# The given sentence is a two-part sentence consisting of a question and an answer. The first part, "Why don't oysters give to charity?" is an interrogative sentence, as it asks a question. The second part, "Because they have no money," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why did the man turn red? Because he saw the neighbour dressing.
# The given sentence is a sentence fragment and contains a grammatical error. A corrected version of the sentence would be: "Why did the man turn red? Because he saw the neighbor undressing."
#
# The first part, "Why did the man turn red?" is an interrogative sentence, as it asks a question. The second part, "Because he saw the neighbor undressing," is a declarative sentence, as it makes a statement.
#
#
# ####
# Why was the belt sent to jail? Because it held up a pair of pants.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the double meaning of the phrase "held up." In one sense, "held up" means to support or keep something in place, as a belt does with a pair of pants. In another sense, "held up" means to rob or steal from someone or something, as a criminal might do to a person or a store. The sentence is a humorous way of using this wordplay to create a punchline.
#
#
# ####
# Why don't skeletons fight each other? They don't have the guts.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the multiple meanings of the word "guts." In one sense, "guts" refers to a person's courage or bravery. In another sense, "guts" refers to a person's internal organs, which skeletons do not have as they are just bones. The sentence is a humorous way of using this wordplay to create a punchline.
#
#
# ####
# Why don't millionaire give to charity? Because he is selfish.
# The sentence "Why don't millionaires give to charity? Because he is selfish." is a declarative sentence, making a statement that implies that millionaires do not donate to charity because they are selfish. However, it is important to note that this statement is not necessarily true, as many millionaires and billionaires are known for their philanthropic efforts and charitable donations. Therefore, the sentence may be considered a false or inaccurate statement, depending on the context in which it is used.
#
#
# ####
# Why was the computer cold? Because it left its Windows open.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the double meaning of the word "Windows." In one sense, "Windows" refers to the operating system developed by Microsoft. In another sense, "windows" refers to the openings in a building that can be opened or closed to let air in or out. The sentence is a humorous way of using this wordplay to create a punchline.
#
#
# ####
# The hipster burned his tongue because he drank his coffee before it was cool.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the double meaning of the word "cool." In one sense, "cool" refers to the temperature of a liquid or food. In another sense, "cool" refers to something that is fashionable or trendy. The sentence is a humorous way of using this wordplay to create a punchline, implying that the hipster drank his coffee before it had cooled down to a safe temperature, but also before it had become "cool" to do so as part of a trend.
#
#
# ####
# Why did the scarecrow win an award? Because he did very good work.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the multiple meanings of the phrase "good work." In one sense, "good work" refers to a job or task that has been performed well. In another sense, "good work" can refer to the physical labor or creation of something, such as a sculpture or painting. The sentence is a humorous way of using this wordplay to create a punchline, implying that the scarecrow's "good work" in scaring away birds was deserving of an award.
#
#
# ####
# Why was the computer cold? Because it was winter.
# The sentence "[...]" is a declarative sentence that states a simple fact. It suggests that the computer was cold due to the cold weather conditions of winter. This sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about a possible reason for the computer being cold.
#
#
# ####
# Why don't oysters give to charity? Because they cannot walk.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the double meaning of the word "give." In one sense, "give" means to make a charitable donation or contribution. In another sense, "give" can refer to physically passing something from one person to another. The sentence is a humorous way of using this wordplay to create a punchline, implying that oysters cannot physically "give" anything to charity because they cannot walk or move.
#
#
# ####
# Scientists don't trust atoms because they make up everything.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the double meaning of the phrase "make up." In one sense, "make up" means to constitute or form something, such as the way that atoms form all matter in the universe. In another sense, "make up" can refer to a person creating a false or exaggerated story or explanation. The sentence is a humorous way of using this wordplay to create a punchline, suggesting that scientists do not trust atoms because they are responsible for everything in the universe, and therefore may be hiding something or creating a false narrative.
#
#
# ####
# Why did the athlete bring two pairs of pants? In case one gets dirty.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the double meaning of the phrase "gets dirty." In one sense, "gets dirty" means to become soiled or stained. In another sense, "gets dirty" can refer to a physical activity or sport that involves getting sweaty or dirty, such as running or playing sports. The sentence is a humorous way of using this wordplay to create a punchline, implying that the athlete brought two pairs of pants in case one becomes soiled or stained from sweat or dirt during a physical activity.
#
#
# ####
# Why did the cow go to outer space? To see the moooon.
# The sentence "[...]" is a joke or a pun. It is a play on words that relies on the similarity between the word "moon" and the sound a cow makes, which is "moo." The sentence is a humorous way of using this wordplay to create a punchline, suggesting that the cow went to outer space in order to see the moon and also to make a play on words with the sound it makes.
#
#
# ####
# Why did the hipster burn his tongue? He drank too hot coffee.
# The sentence "[...]" is a declarative sentence that states a simple fact. It suggests that the hipster burnt his tongue because he drank coffee that was too hot. This sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about a possible reason for the hipster's burnt tongue.
#
#
# ####
# Why did the chicken cross the road? To get to the other side.
# The sentence "[...]" is a classic joke or a pun. It is a play on words that relies on the double meaning of the phrase "the other side." In one sense, "the other side" refers to the opposite side of the road. In another sense, "the other side" can refer to the afterlife, or the other side of the mortal world. The sentence is a humorous way of using this wordplay to create a punchline, implying that the chicken's only motivation for crossing the road was to reach the other side, and that there is no deeper meaning or hidden motive behind its actions.
#
#
# ####
# Why was the student cold? Because it was winter.
# The sentence "[...]" is a declarative sentence that states a simple fact. It suggests that the student was cold because it was winter, which is a common reason for feeling cold during the winter season. This sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about the cause of the student's coldness.
#
#
# ####
# Why did the woman go to the doctor? Because it was feeling crumbly.
# The sentence "Why did the woman go to the doctor? Because it was feeling crumbly" is not grammatically correct as it seems to contain an error in pronoun agreement. The pronoun "it" does not refer to anything in this sentence and does not agree with the subject "the woman." Therefore, it is difficult to determine what kind of sentence it is.
#
# However, if we assume that the sentence was meant to be "Why did the cookie go to the doctor? Because it was feeling crumbly," then it can be interpreted as a joke or a pun. It is a play on words that relies on the double meaning of the word "crumbly." In one sense, "crumbly" refers to the texture of a cookie that is falling apart into crumbs. In another sense, "crumbly" can refer to a feeling of physical discomfort or illness. The sentence is a humorous way of using this wordplay to create a punchline, implying that the cookie went to the doctor because it was feeling physically crumbly or falling apart.
#
#
# ####
# Why did the man turn red? Because he saw the neighbour dressing.
# The sentence "Why did the man turn red? Because he saw the neighbor dressing" is a declarative sentence that states a simple fact. It suggests that the man turned red because he saw his neighbor dressing, which may have caused him embarrassment or discomfort. However, the sentence can also be interpreted as inappropriate or invasive, as it implies that the man was peeping on his neighbor without their consent.
#
# Overall, the sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about the cause of the man's embarrassment or discomfort. However, the content of the sentence may be considered inappropriate or offensive in certain contexts.
#
#
# ####
# Why was the computer cold? Because the was broken.
# The sentence "Why was the computer cold? Because the was broken" is not grammatically correct as it contains an error in the sentence structure and a missing word. It is unclear what the missing word is supposed to be, so it is difficult to determine the intended meaning of the sentence.
#
# However, if we assume that the sentence was meant to be "Why was the computer cold? Because it was broken," then it is a declarative sentence that states a simple fact. It suggests that the computer was cold because it was broken, which may have caused it to stop working or shut down. This sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about the cause of the computer's coldness.
#
#
# ####
# The chicken crossed the road to get to the other side.
# The sentence "The chicken crossed the road to get to the other side" is a declarative sentence that states a simple fact. It suggests that the chicken crossed the road with the purpose of getting to the other side, which is a common reason for chickens to cross roads. This sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about the chicken's action and intention.
#
#
# ####
# Why don't seagulls fly over the bay? Because then are mostly living in ports.
# The sentence "Why don't seagulls fly over the bay? Because then are mostly living in ports" is grammatically incorrect and unclear in meaning. The sentence contains a number of errors, including the incorrect use of "then" instead of "they" and the incorrect verb tense in "living" instead of "live". Additionally, the sentence does not clearly explain the reason why seagulls do not fly over the bay, and the connection between the reason given and the statement in the first part of the sentence is not clear.
#
# Assuming that the intended sentence is "Why don't seagulls fly over the bay? Because they mostly live in ports," then it is a declarative sentence that states a simple fact. It suggests that seagulls tend to live in ports rather than fly over the bay, which may be why they are not commonly seen flying in that area. This sentence is not a joke or a pun and does not rely on any wordplay or double meanings. It is a straightforward statement that conveys information about the behavior and habitat of seagulls.
#
#
# ####
# Oysters don't give to charity because they're shellfish.
# The sentence "Oysters don't give to charity because they're shellfish" is a pun, which is a form of wordplay that uses the multiple meanings of words or their sounds to create a humorous effect. In this sentence, the word "shellfish" is used as a play on words, as it can mean either "selfish" or "a type of seafood with a shell". The sentence suggests that oysters don't donate to charity because they are "shellfish" or selfish, which is a humorous and clever way to use the pun.
#
# Overall, this sentence is not meant to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the multiple meanings of the word "shellfish".
#
#
# ####
# Why did the chicken go to the seance? To talk to the other side.
# The sentence "[...]" is a joke or pun, which is a type of humor that plays with the multiple meanings of words, uses wordplay, or creates unexpected twists or turns. In this sentence, the pun relies on the multiple meanings of "the other side" - in a seance, people attempt to communicate with the dead or the "other side" of life, while the phrase "the other side" can also refer to the opposite side of a road or path.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the multiple meanings of "the other side".
#
#
# ####
# Why was the belt sent to jail? Because it stole a pair of pants.
# The sentence "Why was the belt sent to jail? Because it stole a pair of pants" is a joke or pun, which is a type of humor that plays with the multiple meanings of words, uses wordplay, or creates unexpected twists or turns. In this sentence, the pun relies on the multiple meanings of the word "belt" - it can refer to a waistband worn to hold up pants, or it can also refer to a punishment or penalty.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the multiple meanings of "belt".
#
#
# ####
# The cow went to outer space to see the moooon.
# The sentence "The cow went to outer space to see the moooon" is a joke or pun, which is a type of humor that plays with the multiple meanings of words, uses wordplay, or creates unexpected twists or turns. In this sentence, the pun relies on the similar sounds of "moon" and "moo" - the sound that cows make.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the sounds of "moo" and "moon".
#
#
# ####
# Why couldn't the bicycle stand up by itself? Because it didn't have racks
# The sentence "[...]" is a joke or pun, which is a type of humor that plays with the multiple meanings of words, uses wordplay, or creates unexpected twists or turns. In this sentence, the pun relies on the multiple meanings of "racks" - it can refer to the support bars on a bicycle that hold things, or it can also mean the ability to stand or remain upright without support.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the multiple meanings of "racks".
#
#
# ####
# Why don't seagulls fly over the bay? Because then they'd be bagels.
# The sentence "Why don't seagulls fly over the bay? Because then they'd be bagels" is a joke or pun, which is a type of humor that plays with the multiple meanings of words, uses wordplay, or creates unexpected twists or turns. In this sentence, the pun relies on the similar sounds of "bay-gulls" and "bagels".
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the similar sounds of "bay-gulls" and "bagels".
#
#
# ####
# Why was the novel sad? Because it had too many problems.
# The sentence "Why was the novel sad? Because it had too many problems" is a joke or play on words that relies on the multiple meanings of the word "problems". In this context, "problems" can refer to the difficulties or conflicts within the plot of the novel, but it can also be interpreted as referring to emotional or personal issues of the novel itself.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the multiple meanings of "problems".
#
#
# ####
# The golfer brings two pairs of pants in case he got a hole in one.
# The sentence "The golfer brings two pairs of pants in case he got a hole in one" is a joke or play on words that relies on the double meaning of "hole in one". In golf, a "hole in one" refers to hitting the ball into the hole with just one stroke, which is a rare and impressive feat. However, the sentence also suggests that the golfer may accidentally soil his pants out of excitement or surprise if he were to achieve a hole in one.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words that relies on the double meaning of "hole in one".
#
#
# ####
# The chicken crossed the playground to get to the other slide.
# The sentence "The chicken crossed the playground to get to the other slide" is a joke or play on words that relies on the similarity in pronunciation between the words "slide" and "side".
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words by substituting "slide" for "side" in the well-known joke about the chicken crossing the road.
#
#
# ####
# Why did the computer go to the doctor? Because it was sick.
# The sentence "Why did the computer go to the doctor? Because it was sick" is a joke or play on words that attributes human characteristics to a computer.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a humorous play on words by suggesting that the computer is "sick" in the same way that a human can become ill and need to see a doctor.
#
#
# ####
# Why couldn't the kid stand up by itself? Because it was too tired.
# The sentence "Why couldn't the kid stand up by itself? Because it was too tired" is a joke or play on words that uses a common phrase ("stand up by itself") and attributes it to a child, then provides a humorous explanation for why the child is unable to do so.
#
# The sentence is not intended to be taken literally or convey factual information, but instead to make a play on words and a joke about a child being "too tired" to stand up.
#
#
# ####
# Why don't scientists trust atoms? Because they make up everything.
# The sentence "[...]" is a humorous play on words that relies on a pun. The sentence is not intended to be taken literally or convey factual information about scientists or atoms. Instead, it uses the double meaning of the phrase "make up" to suggest that atoms are not trustworthy because they are the basic building blocks of everything in the universe. The sentence is a type of joke known as a "dad joke" or a "groaner," as it often elicits an eye roll or a groan from the listener.
#
#
# ####
# Why did the teacher go to the doctor? Because he wasn't peeling well.
# The sentence is a pun.
#
#
# ####
# The bicycle couldn't stand up by itself because it was two-tired.
# The sentence is a pun.
#
#
# ####
# Why did the hipster burn his tongue? He drank his coffee before it was cool.
# The sentence is a joke.
#
#
# ####
# The tomato turned red because it saw the salad dressing.
# This is an example of a pun, a play on words where the multiple meanings or similar-sounding words are used for humorous effect. It is not a type of sentence based on grammatical structure or function.
#
#
# ####
# Why did the man go to the doctor? Because he had a virus.
# The sentence "Why did the man go to the doctor? Because he had a virus" is a simple question-and-answer sentence, where the question is seeking for the reason why the man went to the doctor and the answer provides the reason for the man's visit, which is that he had a virus. It is not a joke or a pun.
#
#
# ####
# Why don't schoolboys fight each other? They don't have the guts.
# This is a pun or a play on words that relies on the double meaning of "guts." In one context, "guts" refers to courage or bravery, and in another context, it refers to internal organs. Therefore, this sentence is a joke and not a complete sentence in a grammatical sense.
#
#
# ####
# Why did the teacher go to the doctor? Because he wasn't peeling well.
# This is a pun, or a play on words. The sentence plays with the similarity of the words "peeling" (removing the skin from a fruit or vegetable) and "feeling" (experiencing a particular emotion or sensation).
#
#
# ####
# Why did the swimmer bring two pairs of pants? In case he got a hole in one.
# This is a pun sentence that plays on the phrase "hole in one," which is a term used in golf. The sentence is not grammatically correct, as it doesn't make sense to wear pants while swimming.
#
#
# ####
# Why did the astronaut go to outer space? To see the moon.
# This sentence is a declarative sentence. It makes a statement that the astronaut went to outer space to see the moon.
#
#
# ####
# The scarecrow won an award because he was outstanding in his field.
# This is a pun, a play on words that relies on a double meaning or similar-sounding words to create a humorous effect. In this case, the word "outstanding" can mean either "excellent" or "standing outside" (in a field).
#
#
# ####
# Why did the chicken go to outer space? To see the moon.
# This sentence is a joke or a play on the traditional riddle "Why did the chicken cross the road?" It is not a statement of fact and could be classified as a joke or humorous sentence.
#
#
# ####
# The man put his money in the blender because he wanted to make liquid assets.
# This is a pun, a type of play on words, rather than a sentence with a specific grammatical classification.
#
#
# ####
# Why was the child sad? Because it had too many problems.
# This is a simple declarative sentence.
#
#
# ####
# Why did the boy win an award? Because he did very good work.
# The sentence is a declarative sentence in the past tense.
#
#
# ####
# Why was the student cold? Because the heater was broken.
# This is a simple answer sentence, providing a reason for why the student was cold.
#
#
# ####
# Why was the cashier sent to jail? Because she held up a pair of pants.
# This sentence is a pun, playing with the double meaning of the word "held up." In one sense, it could mean the cashier stopped the customer from leaving and demanded money, which would be a crime. In another sense, it could mean the cashier physically held up a pair of pants to show them to a customer. So it's not possible to classify this sentence as a particular type of sentence.
#
#
# ####
# The math book was sad because it had too many problems.
# This is a joke or pun, rather than a standard sentence. The humor lies in the double meaning of "problems," which can refer to mathematical exercises or difficulties.
#
#
# ####
# Why did the cild cross the playground? To get to the slide.
# The sentence is a statement, stating a reason for the child crossing the playground.
#
#
# ####
# The banana went to the doctor because it wasn't peeling well.
# The sentence is a pun or a play on words, and does not follow standard grammar rules.
#
#
# ####
# Why did the computer go to the doctor? Because it had a byte.
# That sentence is a pun, a type of play on words that exploits multiple meanings of a term or similar-sounding words. Specifically, the pun plays on the homophones "byte" (a unit of digital information) and "bite" (an injury caused by teeth).
#
#
# ####
# Why did the golfer bring two pairs of pants? In case he got a hole in one.
# This is a pun, or a play on words, that relies on the multiple meanings of the phrase "hole in one." It is not a grammatically correct sentence but rather a humorous statement.
#
#
# ####
# Why did the man go to the doctor? Because he had a bite.
# This is a pun sentence. It plays with the word "bite", which can mean a small wound caused by an insect or a computer error when working with digital information. In this case, the sentence uses the double meaning of the word to create a humorous situation.
#
#
# ####
# Why was the woman cold? Because she left its Windows open.
# This sentence contains a pun and a play on words. The sentence is playing with the word "Windows," which can refer to both the operating system developed by Microsoft and the physical openings in a building that allow air to circulate. So, the sentence is a play on the dual meaning of "Windows" and the idea of leaving a window open causing someone to feel cold. Therefore, this sentence is a type of pun or wordplay.
#
#
# ####
# What do you call an alligator in a vest? An investigator.
# This is a type of joke known as a pun.
#
#
# ####
# Why did the frog call his insurance company? He had a scratch in his car.
# This is a type of joke known as a pun.
#                                                prompt  \
# 0   The belt was sent to jail because it held up a...
# 0   Why don't schoolboys fight each other? They do...
# 0   Why don't seagulls fly over the bay? Because t...
# 0   Why did the chicken cross the road? To get to ...
# 0   What do you call an alligator in a vest? An in...
# ..                                                ...
# 0   Why did the golfer bring two pairs of pants? I...
# 0   Why did the man go to the doctor? Because he h...
# 0   Why was the woman cold? Because she left its W...
# 0   What do you call an alligator in a vest? An in...
# 0   Why did the frog call his insurance company? H...
#
#                                              response
# 0   The sentence is an example of a personificatio...
# 0   The first sentence is an interrogative sentenc...
# 0   The first sentence is an interrogative sentenc...
# 0   The first sentence is an interrogative sentenc...
# 0   The sentence is an example of a joke or pun. T...
# ..                                                ...
# 0   This is a pun, or a play on words, that relies...
# 0   This is a pun sentence. It plays with the word...
# 0   This sentence contains a pun and a play on wor...
# 0          This is a type of joke known as a pun.\n\n
# 0          This is a type of joke known as a pun.\n\n
#
# [83 rows x 2 columns]

# %% [markdown]
# ---
# ---
# ---
# ## read reaults from new detection

# %%
import pandas as pd

jokes = [
    "Why did the scarecrow win an award? Because he was outstanding in his field.",
    "Why did the tomato turn red? Because it saw the salad dressing.",
    "Why was the math book sad? Because it had too many problems.",
    "Why don't scientists trust atoms? Because they make up everything.",
    "Why did the cookie go to the doctor? Because it was feeling crumbly.",
    "Why couldn't the bicycle stand up by itself? Because it was two-tired.",
    "Why did the frog call his insurance company? He had a jump in his car.",
    "Why did the chicken cross the playground? To get to the other slide.",
    "Why was the computer cold? Because it left its Windows open.",
    "Why did the hipster burn his tongue? He drank his coffee before it was cool.",
    "Why don't oysters give to charity? Because they're shellfish.",
    "Why did the computer go to the doctor? Because it had a virus.",
    "Why did the banana go to the doctor? Because it wasn't peeling well.",
    "Why did the coffee file a police report? Because it got mugged.",
    "Why did the golfer bring two pairs of pants? In case he got a hole in one.",
    "Why did the man put his money in the freezer? He wanted cold hard cash.",
    "Why don't seagulls fly over the bay? Because then they'd be bagels.",
    "Why did the chicken go to the seance? To talk to the other side.",
    "Why was the belt sent to jail? Because it held up a pair of pants.",
    "Why did the chicken cross the road? To get to the other side.",
    "Why did the computer go to the doctor? Because it had a byte.",
    "Why did the cow go to outer space? To see the moooon.",
    "Why did the man put his money in the blender? He wanted to make liquid assets.",
    "Why don't skeletons fight each other? They don't have the guts.",
    "What do you call an alligator in a vest? An investigator.",
]

jokes_onesen = [
    "The scarecrow won an award because he was outstanding in his field.",
    "The tomato turned red because it saw the salad dressing.",
    "The math book was sad because it had too many problems.",
    "Scientists don't trust atoms because they make up everything.",
    "The cookie went to the doctor because it was feeling crumbly.",
    "The bicycle couldn't stand up by itself because it was two-tired.",
    "The frog called his insurance company because he had a jump in his car.",
    "The chicken crossed the playground to get to the other slide.",
    "The computer was cold because it left its Windows open.",
    "The hipster burned his tongue because he drank his coffee before it was cool.",
    "Oysters don't give to charity because they're shellfish.",
    "The computer went to the doctor because it had a virus.",
    "The banana went to the doctor because it wasn't peeling well.",
    "The coffee filed a police report because it got mugged.",
    "The golfer brings two pairs of pants in case he got a hole in one.",
    "The man put his money in the freezer because he wanted cold hard cash.",
    "Seagulls don't fly over the bay because then they'd be bagels.",
    "The chicken went to the seance to talk to the other side.",
    "The belt was sent to jail because it held up a pair of pants.",
    "The chicken crossed the road to get to the other side.",
    "The computer went to the doctor because it had a byte.",
    "The cow went to outer space to see the moooon.",
    "The man put his money in the blender because he wanted to make liquid assets.",
    "Skeletons don't fight each other because they don't have the guts.",
    "An alligator in a vest is called an investigator.",
]

noj1 = [ # without wordplay, but with picutre
    "Why did the scarecrow win an award? Because he did very good work.",
    "Why did the tomato turn red? Because it had a lot sun recently.",
    "Why was the math book sad? Because it was a rainy day.",
    "Why don't scientists trust atoms? Because they tend to lie.",
    "Why did the cookie go to the doctor? Because it was feeling unwell.",
    "Why couldn't the bicycle stand up by itself? Because it didn't have racks.",
    "Why did the frog call his insurance company? He had a scratch in his car.",
    #"Why did the oyster cross the playground? To get to the other slide.", ###
    "Why was the computer cold? Because the heater was broken.",
    "Why did the hipster burn his tongue? He drank hot coffee.",
    "Why don't oysters give to charity? Because they have no money.",
    "Why did the computer go to the doctor? Because it had a sick.",
    "Why did the banana go to the doctor? Because it was sick.",
    "Why did the coffee file a police report? Because it got robbed.",
    "Why did the golfer bring two pairs of pants? In case one gets damaged.", ###
    # "Why did the man put his money in the freezer? He wanted cold hard cash.",
    "Why don't seagulls fly over the bay? Because then are mostly living in ports.",
    #"Why did the chicken go to the seance? To talk to the other side.",
    "Why was the belt sent to jail? Because it stole in a store.",
   # "Why did the chicken cross the road? To get to the other side.",
    "Why did the computer go to the doctor? Because it had a headache.",
    "Why did the chicken go to outer space? To see the moon.",
   # "Why did the man put bananas in the blender? He wanted to make liquid assets.",
    "Why don't skeletons fight each other? They are dead already.",
    #"What do you call an alligator in a vest? An investigator.",
]

noj2 = [ # without picture
    "Why did the scientist win an award? Because he did very good work.",
    "Why did the man turn red? Because he saw the neighbour dressing.",#"Why did the tomato turn red? Because it saw the salad dressing.",
    "Why was the child sad? Because it had many problems.",
    "Why don't scientists trust journalists? Because they make up everything.",
    "Why did the woman go to the doctor? Because it was feeling crumbly.",
    "Why couldn't the man stand up by itself? Because he was drunk.",
    "Why did the driver call his insurance company? He had a jump in his car.",
    "Why did the kid cross the playground? To get to the other slide.",
    "Why was the student cold? Because it was winter.",
    "Why did the coworker burn his tongue? He drank his coffee too hot.",
    "Why don't millionaires give to charity? Because they're selfish.",
    "Why did the man go to the doctor? Because it had a virus.",
    "Why did the teacher go to the doctor? Because it wasn't peeling well.",
    "Why did the driver file a police report? Because it got robbed.",
    "Why did the athlete bring two pairs of pants? In case one gets dirty.",
    "Why did the man put his money in the freezer? To hide it from intruders.",
    "Why don't pigeon fly over the bay? Because they mostly live in cities.",
    "Why did the daughter go to the seance? To talk to her mother.",
    "Why was the cashier sent to jail? Because she held up a dress.",
    "Why did the man cross the road? To get to the other side.",
    "Why did the man go to the doctor? Because he had a bite.",
    "Why did the astronaut go to outer space? To see the moon.",
    "Why did the man put bananas in the blender? He wanted to make a smoothie.", 
    "Why don't schoolboys fight each other? They don't have the guts.",
    "What do you call an man in a vest? A vest wearer.", 
]


df = pd.read_pickle("joke_detection_new")


for i in range(df.shape[0] ): 
    try: 
        df.iloc[i,1] = df.iloc[i,1]['message']
        df.iloc[i,0] = df.iloc[i,0].replace('What kind of sentence is that: ', "")
        df.iloc[i,1] = df.iloc[i,1].replace(df.iloc[i,0], "[...]")
    #df.iloc[i,1] = df.iloc[i,1].replace('"[...]"', "[...]")
    except:
        None
def done():

    for i in range(df.shape[0] ):
        print('####')
        print(df.iloc[i,0])
        print(df.iloc[i,1])



df

# %%
alldf.to_pickle("joke_detection_new")

# %%
all = jokes + jokes_onesen + noj1 + noj2
alls = list(set(all))
#all.sort()
#alls.sort()

alldf = pd.read_pickle("joke_detection_new")

# here i sort the responses. i randomised the order for scientific reasons
sortid = []
for elem in alldf.prompt.tolist():
    for i in range(len(all)):
        if all[i] in elem:
            #print(i, elem)
            sortid.append(i)

alldf = alldf.reset_index(drop=True)
#alldf.drop("index", axis=1)
alldf
# Out:
#                                                prompt  \
# 0   Why don't seagulls fly over the bay? Because t...
# 1   Why don't oysters give to charity? Because the...
# 2   Why did the man go to the doctor? Because he h...
# 3   The cookie went to the doctor because it was f...
# 4   Why couldn't the bicycle stand up by itself? B...
# ..                                                ...
# 89  Why did the man go to the doctor? Because it h...
# 90  Why did the coffee file a police report? Becau...
# 91  The man put his money in the freezer because h...
# 92  An alligator in a vest is called an investigator.
# 93  Why did the tomato turn red? Because it had a ...
#
#                                              response
# 0   The sentence is a complex sentence with two cl...
# 1   The sentence is a complex sentence consisting ...
# 2   The sentence "[...]" is a pair of sentences, w...
# 3   The sentence "The cookie went to the doctor be...
# 4   The sentence "Why couldn't the bicycle stand u...
# ..                                                ...
# 89  The sentence "[...]" is an example of a senten...
# 90  The given sentence is a joke or a pun, which r...
# 91  The sentence "The man put his money in the fre...
# 92  The sentence "An alligator in a vest is called...
# 93  The given sentence "Why did the tomato turn re...
#
# [94 rows x 2 columns]

# %%
alldf['position'] = sortid
alldf = alldf.set_index('position')
alldf

alldf = alldf.sort_index()

alldf
# Out:
#                                                      prompt  \
# position
# 0         Why did the scarecrow win an award? Because he...
# 1         Why did the tomato turn red? Because it saw th...
# 2         Why was the math book sad? Because it had too ...
# 3         Why don't scientists trust atoms? Because they...
# 4         Why did the cookie go to the doctor? Because i...
# ...                                                     ...
# 89        Why did the man go to the doctor? Because he h...
# 90        Why did the astronaut go to outer space? To se...
# 91        Why did the man put bananas in the blender? He...
# 92        Why don't schoolboys fight each other? They do...
# 93        What do you call an man in a vest? A vest wearer.
#
#                                                    response
# position
# 0         This is a joke or pun sentence that plays on t...
# 1         The given text is a joke, not a standard sente...
# 2         The sentence "Why was the math book sad? Becau...
# 3         The sentence "[...]" is a joke or a play on wo...
# 4         The sentence "Why did the cookie go to the doc...
# ...                                                     ...
# 89        The sentence "[...]" is a pair of sentences, w...
# 90        The first sentence "Why did the astronaut go t...
# 91        The first sentence is an interrogative sentenc...
# 92        The first sentence, "Why don't schoolboys figh...
# 93        The sentence is a question followed by an answ...
#
# [94 rows x 2 columns]

# %%
for i in range(alldf.shape[0] ):
    print('####')
    print(alldf.iloc[i,0])
    print(alldf.iloc[i,1])
# Out:
# ####
# Why did the scarecrow win an award? Because he was outstanding in his field.
# This is a joke or pun sentence that plays on the double meaning of the phrase "outstanding in his field." The sentence is structured as a question and answer format, with the question being "Why did the scarecrow win an award?" and the answer being "Because he was outstanding in his field."
#
#
# ####
# Why did the tomato turn red? Because it saw the salad dressing.
# The given text is a joke, not a standard sentence with a specific grammatical form.
#
# However, if we were to analyze the sentence structure, the first sentence "Why did the tomato turn red?" is an interrogative sentence or a question, and the second sentence "Because it saw the salad dressing" is a declarative sentence, which provides an answer to the previous question.
#
#
# ####
# Why was the math book sad? Because it had too many problems.
# The sentence "Why was the math book sad? Because it had too many problems" is a joke or a pun, as it uses a play on words to create humor. It is a question-and-answer format, where the question sets up the joke and the answer delivers the punchline.
#
#
# ####
# Why don't scientists trust atoms? Because they make up everything.
# The sentence "[...]" is a joke or a play on words. It is a type of humor known as a "pun."
#
#
# ####
# Why did the cookie go to the doctor? Because it was feeling crumbly.
# The sentence "Why did the cookie go to the doctor? Because it was feeling crumbly" is a joke or a riddle. It is a type of humorous question and answer format that is intended to be funny.
#
#
# ####
# Why couldn't the bicycle stand up by itself? Because it was two-tired.
# The sentence is a joke or a pun, which is a form of wordplay that exploits multiple meanings of a term, or of similar-sounding words, for humorous effect. In this case, the word "tired" is used in two ways: first, as an adjective to describe the condition of the bicycle, which has two wheels; and second, as a homophone of the word "tired," meaning exhausted, which creates a play on words.
#
#
# ####
# Why did the frog call his insurance company? He had a jump in his car.
# The sentence is a pun or a play on words, as it relies on a double meaning of the word "jump." In the context of the sentence, "jump" can refer to either the act of leaping or to a malfunction in a car's electrical system that causes a temporary loss of power.
#
# The sentence is structured as a question, "Why did the frog call his insurance company?" which is then followed by a punny answer, "He had a jump in his car." Therefore, it can be classified as a joke or a riddle.
#
#
# ####
# Why did the chicken cross the playground? To get to the other slide.
# The sentence is a joke, specifically a type of joke called a "punchline," where the setup (the question "Why did the chicken cross the playground?") leads to an unexpected or humorous conclusion (the answer "To get to the other slide"). From a grammatical perspective, the sentence is a simple declarative sentence with a subject ("the chicken") and predicate ("crossed the playground to get to the other slide").
#
#
# ####
# Why was the computer cold? Because it left its Windows open.
# The sentence is a play on words and is a type of joke called a pun. It includes a question ("Why was the computer cold?") and an answer ("Because it left its Windows open"), which is a pun because it uses the double meaning of "Windows" as both the name of a computer operating system and a type of opening that allows air to pass through. The sentence is not a declarative or imperative sentence but rather a joke or riddle.
#
#
# ####
# Why did the hipster burn his tongue? He drank his coffee before it was cool.
# The sentence "Why did the hipster burn his tongue? He drank his coffee before it was cool" is a joke or a pun. It plays with the double meaning of the word "cool," which can refer to the temperature of the coffee or to the hipster's desire to be trendy and fashionable. The sentence is a combination of a question and an answer that provides the punchline of the joke.
#
#
# ####
# Why don't oysters give to charity? Because they're shellfish.
# The sentence is a play on words and is a type of pun. It is a joke that relies on the double meaning of the word "shellfish." In this context, "shellfish" refers to oysters, which are animals that live inside a shell. However, "shellfish" can also mean a person who is selfish and doesn't like to share. The sentence is a play on this double meaning, and the punchline is a twist on the expected answer to the question "why don't oysters give to charity?"
#
#
# ####
# Why did the computer go to the doctor? Because it had a virus.
# The sentence "[...]" is a typical example of a joke or a riddle. It is a question-and-answer format in which the question sets up an expectation for a serious or logical answer, but the answer delivers a humorous twist or a pun.
#
#
# ####
# Why did the banana go to the doctor? Because it wasn't peeling well.
# The sentence is a joke or a riddle. It is not a type of sentence based on its grammatical structure or function, but rather a statement intended to be humorous by presenting a question and then providing a pun or unexpected answer.
#
#
# ####
# Why did the coffee file a police report? Because it got mugged.
# The sentence is a joke, which is a type of figurative language that is intended to be humorous or entertaining. More specifically, it is a play on words, or a pun, that relies on the double meaning of the word "mugged" (i.e., robbed and also made into coffee). The first part of the sentence is a question and the second part is the punchline, which provides the unexpected answer.
#
#
# ####
# Why did the golfer bring two pairs of pants? In case he got a hole in one.
# The sentence is a joke, known as a "pun," and it is a simple interrogative sentence. The question "Why did the golfer bring two pairs of pants?" sets up the punchline, which is a play on words with the phrase "hole in one," which can refer to a perfect shot in golf or a hole in one's pants.
#
#
# ####
# Why did the man put his money in the freezer? He wanted cold hard cash.
# The sentence is a play on words, using a pun to create a joke. Grammatically, it is a simple interrogative sentence followed by a declarative sentence.
#
#
# ####
# Why don't seagulls fly over the bay? Because then they'd be bagels.
# The sentence is a joke or a pun. It is a play on words between "seagulls" and "bagels" as they sound similar, and the sentence uses this similarity to create a humorous effect. It is not a serious question or statement, but rather a humorous way of playing with language.
#
#
# ####
# Why did the chicken go to the seance? To talk to the other side.
# The sentence is a joke, which uses a play on words. It is a type of pun, where the humor comes from the use of the word "other side" in two different contexts. In this case, the word "other side" can mean the spirit world that is communicated with during a séance, and also the other side of the road, which is a common reason for a chicken to cross. Therefore, the sentence can be categorized as a joke or a pun.
#
#
# ####
# Why was the belt sent to jail? Because it held up a pair of pants.
# The sentence "Why was the belt sent to jail? Because it held up a pair of pants" is a joke or a pun. It is a play on words, using the double meaning of the phrase "held up." In this context, "held up" can mean both "supported" (in the case of holding up pants) and "robbed at gunpoint" (in the case of a hold-up). So the sentence is a type of wordplay that is intended to be humorous.
#
#
# ####
# Why did the chicken cross the road? To get to the other side.
# This is a commonly known joke and can be classified as a "riddle" or a "puzzle" type of sentence. The question "Why did the chicken cross the road?" sets up the expectation of a clever or unexpected answer, and the punchline "To get to the other side" delivers that payoff. It is not a declarative, interrogative, imperative, or exclamatory sentence in the traditional grammatical sense, as it is a constructed to be a humorous play on words.
#
#
# ####
# Why did the computer go to the doctor? Because it had a byte.
# The sentence "[...]" is a joke or a pun. It plays on the double meaning of the word "byte," which can refer to a unit of digital information, but also sounds like "bite," which is a common reason for humans to go to the doctor. This type of sentence is often called a "dad joke" or a "punny joke" and is meant to be humorous.
#
#
# ####
# Why did the cow go to outer space? To see the moooon.
# The given sentence is a joke or a riddle, which is a type of sentence used to amuse or entertain someone with a play on words or a humorous question.
#
#
# ####
# Why did the man put his money in the blender? He wanted to make liquid assets.
# The sentence is a play on words and can be classified as a joke or a pun. It consists of two parts: a question and a punchline. The question "Why did the man put his money in the blender?" sets up the joke, and the answer "He wanted to make liquid assets" is the punchline, which relies on a play on words between the literal meaning of "liquid assets" (i.e., assets that can easily be converted to cash) and the figurative meaning of "liquid" in the context of a blender.
#
#
# ####
# Why don't skeletons fight each other? They don't have the guts.
# The sentence is a joke that plays on the double meaning of the word "guts". It is a declarative sentence that also serves as a pun.
#
#
# ####
# What do you call an alligator in a vest? An investigator.
# The sentence is a joke or a riddle. It is a simple question-and-answer format where the question asks for the name of something in a particular situation, and the answer provides a play on words that is unexpected and humorous.
#
#
# ####
# The scarecrow won an award because he was outstanding in his field.
# The sentence "The scarecrow won an award because he was outstanding in his field" is a pun, a form of wordplay that relies on a double meaning of a word or phrase. In this case, the phrase "outstanding in his field" has a literal meaning (i.e., the scarecrow is excellent at standing in the field) and a figurative meaning (i.e., the scarecrow is exceptional in his area of expertise or work). The pun is created by using the literal meaning of the phrase to describe the scarecrow's physical location and the figurative meaning to suggest that he deserved an award for his outstanding performance or achievements.
#
#
# ####
# The tomato turned red because it saw the salad dressing.
# The sentence "The tomato turned red because it saw the salad dressing" is an example of an incorrect or nonsensical sentence. While it is grammatically correct, the content of the sentence is not accurate or logical. Tomatoes do not have the ability to see, so it is not possible for a tomato to turn red because it saw salad dressing. Therefore, this sentence is an example of a semantic error or a nonsensical sentence.
#
#
# ####
# The math book was sad because it had too many problems.
# The sentence "The math book was sad because it had too many problems" is an example of personification, where human qualities are attributed to a non-human entity. In this case, the math book is being described as if it were a person capable of feeling sadness. The sentence is a declarative sentence, as it makes a statement.
#
#
# ####
# Scientists don't trust atoms because they make up everything.
# The sentence "Scientists don't trust atoms because they make up everything" is a humorous play on words, and it is a type of joke known as a "pun." It is not meant to be taken literally, as scientists do trust atoms and recognize their fundamental role in the composition of matter. However, the sentence is structured as a complex sentence, with a dependent clause ("because they make up everything") and an independent clause ("Scientists don't trust atoms").
#
#
# ####
# The cookie went to the doctor because it was feeling crumbly.
# The sentence "The cookie went to the doctor because it was feeling crumbly" is an example of a personification, where an inanimate object (in this case, a cookie) is given human-like qualities or actions. It is a declarative sentence, as it makes a statement, and it uses past tense.
#
#
# ####
# The bicycle couldn't stand up by itself because it was two-tired.
# The sentence "The bicycle couldn't stand up by itself because it was two-tired" is a pun, which is a form of wordplay that uses multiple meanings or similar-sounding words to create a humorous or clever effect. In this case, the pun plays on the double meaning of the word "tired," which can mean "exhausted" or "having tires." The sentence is also a declarative sentence, as it makes a statement.
#
#
# ####
# The frog called his insurance company because he had a jump in his car.
# The sentence is a play on words and is classified as a pun. It uses the homophones "jump" and "jumper" to create a humorous situation where a frog is calling his insurance company because he had a jump in his car, implying that he hit something while driving.
#
#
# ####
# The chicken crossed the playground to get to the other slide.
# The sentence "[...]" is a declarative sentence. It makes a statement and provides information about the subject, which is "the chicken." Specifically, the sentence describes the action taken by the chicken, which is to cross the playground to get to the other slide.
#
#
# ####
# The computer was cold because it left its Windows open.
# The sentence "The computer was cold because it left its Windows open" is a simple declarative sentence. It contains a subject ("the computer") and a predicate ("was cold because it left its Windows open"), and it makes a statement or assertion about the subject.
#
#
# ####
# The hipster burned his tongue because he drank his coffee before it was cool.
# The sentence "The hipster burned his tongue because he drank his coffee before it was cool" is a declarative sentence. It is a statement that conveys information or makes a statement about something. Specifically, this sentence describes an event that happened to a person because of their actions.
#
#
# ####
# Oysters don't give to charity because they're shellfish.
# The sentence "Oysters don't give to charity because they're shellfish" is a pun or a play on words. It uses the word "shellfish" in two different ways - the literal meaning of "oysters being shellfish" and the figurative meaning of "being selfish". The pun is intended to be humorous and clever. Grammatically, it is a declarative sentence, as it makes a statement.
#
#
# ####
# The computer went to the doctor because it had a virus.
# The sentence "The computer went to the doctor because it had a virus" is a declarative sentence. It makes a statement and ends with a period.
#
#
# ####
# The banana went to the doctor because it wasn't peeling well.
# The sentence "The banana went to the doctor because it wasn't peeling well" is a declarative sentence. It makes a statement, and it ends with a period. Specifically, it is a simple sentence because it contains only one independent clause.
#
#
# ####
# The coffee filed a police report because it got mugged.
# The sentence is a personification, where an inanimate object, in this case, "coffee," is given human-like qualities and actions. In the sentence, the coffee is said to have filed a police report and got mugged, which are actions typically associated with humans.
#
#
# ####
# The golfer brings two pairs of pants in case he got a hole in one.
# The sentence is a simple declarative sentence. It expresses a complete thought and makes a statement about the golfer and his preparation for a potential situation.
#
#
# ####
# The man put his money in the freezer because he wanted cold hard cash.
# The sentence "The man put his money in the freezer because he wanted cold hard cash" is a declarative sentence, which is a statement that makes a statement or provides information. Specifically, this sentence provides information about what the man did with his money and why he did it.
#
#
# ####
# Seagulls don't fly over the bay because then they'd be bagels.
# The sentence "Seagulls don't fly over the bay because then they'd be bagels" is a humorous and nonsensical statement often used as a joke. Grammatically, it is a simple declarative sentence in the present tense, with a conditional clause in the second part of the sentence.
#
#
# ####
# The chicken went to the seance to talk to the other side.
# The sentence "The chicken went to the seance to talk to the other side" is a declarative sentence. It makes a statement or expresses a fact. In this case, the sentence describes an action taken by a chicken, which is unusual and may be intended to be humorous or absurd.
#
#
# ####
# The belt was sent to jail because it held up a pair of pants.
# This sentence is an example of a humorous or nonsensical sentence. It is a play on words and contains a pun. The sentence is not intended to be taken literally, but instead, it is meant to be amusing.
#
#
# ####
# The chicken crossed the road to get to the other side.
# The sentence "The chicken crossed the road to get to the other side" is a declarative sentence. It presents a statement or fact, in this case, that a chicken crossed the road for a specific purpose.
#
#
# ####
# The computer went to the doctor because it had a byte.
# The sentence is a pun or a play on words. The word "byte" in the sentence is a homophone for "bite," which means to take a mouthful of something. In this context, the computer cannot physically take a bite, so it must be referring to a byte, which is a unit of digital information. The sentence is a play on words, making it a type of humorous sentence.
#
#
# ####
# The cow went to outer space to see the moooon.
# The sentence "The cow went to outer space to see the moooon" is a declarative sentence. It makes a statement and ends with a period. However, the sentence is also a nonsensical statement as cows cannot travel to outer space.
#
#
# ####
# The man put his money in the blender because he wanted to make liquid assets.
# The sentence "The man put his money in the blender because he wanted to make liquid assets" is a joke or pun, as it plays on the double meaning of the phrase "liquid assets" (meaning cash or other assets that can be easily converted to cash, and also meaning a liquid substance). However, grammatically, the sentence is a simple declarative sentence.
#
#
# ####
# Skeletons don't fight each other because they don't have the guts.
# The sentence is a pun or play on words, as it uses the idiom "have the guts" to mean "have the courage" or "have the nerve", but in this case, it is also a literal reference to the fact that skeletons don't have any internal organs, including guts. In terms of grammatical structure, the sentence is a simple declarative sentence in the present tense with a compound predicate.
#
#
# ####
# An alligator in a vest is called an investigator.
# The sentence "An alligator in a vest is called an investigator" is a type of wordplay called a pun. Specifically, it is a play on words that involves the use of two words that sound similar but have different meanings, in this case "alligator" and "investigator".
#
#
# ####
# Why did the scarecrow win an award? Because he did very good work.
# The sentence "Why did the scarecrow win an award? Because he did very good work" is a dialogue or conversation. It consists of two parts: a question and an answer. The first part is a question that is asking for information, and the second part is an answer that provides the information being sought.
#
#
# ####
# Why did the tomato turn red? Because it had a lot sun recently.
# The given sentence "Why did the tomato turn red? Because it had a lot sun recently" is a complex sentence. It consists of two clauses, a main clause and a subordinate clause.
#
# The main clause is "Why did the tomato turn red?" which is an interrogative sentence as it asks a question.
#
# The subordinate clause is "Because it had a lot sun recently" which provides the reason for the question asked in the main clause. This clause is a dependent clause as it cannot stand alone as a sentence. It is introduced by the subordinating conjunction "because" and functions as an adverbial clause, modifying the verb "turn" in the main clause.
#
#
# ####
# Why was the math book sad? Because it was a rainy day.
# The sentence "[...]" is a joke or a riddle. It is not a statement or question seeking a straightforward answer, but rather a play on words that uses a humorous twist to create a surprise ending.
#
#
# ####
# Why don't scientists trust atoms? Because they tend to lie.
# The sentence is a joke, playing on the double meaning of the word "lie". It is a type of humor called a pun.
#
# Structurally, the sentence consists of two parts: a question and an answer. The question is "Why don't scientists trust atoms?" and the answer is "Because they tend to lie."
#
# Therefore, the sentence is a simple joke or pun, rather than a declarative, interrogative, or imperative sentence.
#
#
# ####
# Why did the cookie go to the doctor? Because it was feeling unwell.
# The sentence "Why did the cookie go to the doctor? Because it was feeling unwell" is a joke or a riddle. It is a question and answer format that is commonly used in humor or to challenge the listener to think creatively.
#
#
# ####
# Why couldn't the bicycle stand up by itself? Because it didn't have racks.
# The sentence "Why couldn't the bicycle stand up by itself? Because it didn't have racks" is a joke. It's a play on words, using the word "racks" as both a noun (referring to a bicycle rack, which is a structure that holds a bicycle upright) and as a verb (meaning "to be unable to stand or support oneself"). It's a type of pun or wordplay that is often used in humor. In terms of grammatical structure, it's a compound-complex sentence with an interrogative clause ("Why couldn't the bicycle stand up by itself?") and a declarative clause ("Because it didn't have racks").
#
#
# ####
# Why did the frog call his insurance company? He had a scratch in his car.
# The sentence "[...]" is a joke or a riddle. It is a question-and-answer type of sentence that presents a humorous situation.
#
#
# ####
# Why was the computer cold? Because the heater was broken.
# The sentence "Why was the computer cold? Because the heater was broken" is a complex sentence. It consists of two clauses - an independent clause and a dependent clause.
#
# The independent clause is "the heater was broken," which can stand alone as a complete sentence.
#
# The dependent clause is "Why was the computer cold?", which cannot stand alone as a complete sentence and depends on the independent clause to make sense.
#
# The two clauses are connected by the subordinating conjunction "because," which indicates that the reason for the computer being cold is the fact that the heater was broken.
#
#
# ####
# Why did the hipster burn his tongue? He drank hot coffee.
# The sentence "[...]" is a simple two-part question and answer construction. The first part of the sentence is an interrogative sentence (a question), and the second part is a declarative sentence (a statement).
#
#
# ####
# Why don't oysters give to charity? Because they have no money.
# The sentence is a complex sentence consisting of two clauses: a main clause and a subordinate clause. The main clause is "Because they have no money," and the subordinate clause is "Why don't oysters give to charity?"
#
# The subordinate clause is a question that functions as the cause or reason for the main clause. The main clause provides the answer or explanation to the question posed in the subordinate clause. Therefore, this sentence is an example of a complex sentence that uses cause and effect.
#
#
# ####
# Why did the computer go to the doctor? Because it had a sick.
# The sentence "[...]" is a joke or a riddle, rather than a typical sentence. It plays on the double meaning of "sick", which can refer to an illness in humans or to a malfunction in a machine. The sentence is a question followed by a punchline, with the unexpected answer adding humor to the joke.
#
#
# ####
# Why did the banana go to the doctor? Because it was sick.
# The sentence "Why did the banana go to the doctor? Because it was sick" is a joke or a riddle. It is a type of question and answer format commonly used in humor or as a way to engage someone in a playful way.
#
#
# ####
# Why did the coffee file a police report? Because it got robbed.
# The given sentence is a joke or a pun, which relies on wordplay for its humor. The first part of the sentence sets up an expectation that the coffee is a victim of a crime, and the second part of the sentence delivers an unexpected twist by using the word "robbed" in a humorous way. Therefore, the sentence can be categorized as a pun.
#
#
# ####
# Why did the golfer bring two pairs of pants? In case one gets damaged.
# The sentence "[...]" is a complex sentence that consists of two clauses. The first clause is a subordinate clause that functions as an adverbial clause of reason, starting with the subordinating conjunction "Why". The second clause is the main clause that provides the answer to the question asked in the first clause. It is a declarative sentence that states the reason why the golfer brought two pairs of pants.
#
#
# ####
# Why don't seagulls fly over the bay? Because then are mostly living in ports.
# The sentence is a complex sentence with two clauses: a main clause and a subordinate clause.
#
# The main clause is "Why don't seagulls fly over the bay?", which is an interrogative sentence that asks a question.
#
# The subordinate clause is "Because then are mostly living in ports.", which is a declarative sentence that provides an explanation or reason for the question asked in the main clause. This subordinate clause starts with the subordinating conjunction "because" and it cannot stand alone as a complete sentence.
#
# A corrected version of the sentence with proper grammar would be: "Why don't seagulls fly over the bay? Because they mostly live in ports."
#
#
# ####
# Why was the belt sent to jail? Because it stole in a store.
# The sentence "Why was the belt sent to jail? Because it stole in a store" is a pair of sentences combined with a conjunction.
#
# The first sentence is an interrogative sentence that asks a question. The question is asking for a reason or cause of something, which in this case is why the belt was sent to jail.
#
# The second sentence is a declarative sentence that provides the reason or cause for why the belt was sent to jail. It explains that the belt stole in a store.
#
# Together, these two sentences form a simple compound sentence.
#
#
# ####
# Why did the computer go to the doctor? Because it had a headache.
# The sentence "[...]" is a joke or riddle. It is a play on words that relies on a pun to create a humorous effect.
#
#
# ####
# Why did the chicken go to outer space? To see the moon.
# The sentence "[...]" is a joke or riddle. It uses wordplay to create a humorous situation by posing a nonsensical question and answering it with an unexpected and humorous answer.
#
#
# ####
# Why don't skeletons fight each other? They are dead already.
# The given sentence is a declarative sentence. It makes a statement or expresses a fact. The statement in this sentence is that skeletons do not fight each other because they are already dead.
#
#
# ####
# Why did the scientist win an award? Because he did very good work.
# The first sentence "Why did the scientist win an award?" is an interrogative sentence, which is used to ask a question.
#
# The second sentence "Because he did very good work." is a declarative sentence, which is used to make a statement or provide an explanation.
#
#
# ####
# Why did the man turn red? Because he saw the neighbour dressing.
# The given sentence is a complex sentence consisting of two clauses.
#
# The first clause is an interrogative clause: "Why did the man turn red?" It is a question, indicating that the speaker is seeking information about the reason behind the man turning red.
#
# The second clause is an independent clause: "Because he saw the neighbour dressing." It provides the reason or explanation for the man turning red. This clause begins with the subordinating conjunction "because", which signals a cause-and-effect relationship between the two clauses.
#
#
# ####
# Why was the child sad? Because it had many problems.
# The sentence "[...]" is a complex sentence. It consists of two clauses, an independent clause "Why was the child sad?" and a dependent clause "Because it had many problems." The dependent clause is introduced by the subordinating conjunction "because," and it provides an explanation or reason for the independent clause.
#
#
# ####
# Why don't scientists trust journalists? Because they make up everything.
# The sentence is a complex sentence with a subordinate clause and an independent clause. The subordinate clause is "Why don't scientists trust journalists?" which functions as a dependent clause because it cannot stand alone as a complete sentence. The independent clause is "Because they make up everything," which contains the main idea of the sentence and can stand alone as a complete sentence. The conjunction "because" is used to connect the two clauses, indicating that the reason for scientists not trusting journalists is that journalists make up everything.
#
#
# ####
# Why did the woman go to the doctor? Because it was feeling crumbly.
# The sentence "[...]" is a grammatically incorrect sentence. It appears to be a combination of two separate sentences, one that asks why the woman went to the doctor, and another that provides a reason for her visit.
#
# To make this sentence grammatically correct, it could be rephrased as "Why did the woman go to the doctor? She went because she was feeling crumbly."
#
#
# ####
# Why couldn't the man stand up by itself? Because he was drunk.
# The first sentence is an interrogative sentence (a question) that asks why the man couldn't stand up. The second sentence is a declarative sentence (a statement) that provides the answer to the question by stating that the man was drunk. Together, they form a question and answer sequence.
#
#
# ####
# Why did the driver call his insurance company? He had a jump in his car.
# The sentence is a simple declarative sentence with two parts, separated by the conjunction "He." The first part is a question: "Why did the driver call his insurance company?" The second part provides the answer to the question: "He had a jump in his car."
#
#
# ####
# Why did the kid cross the playground? To get to the other slide.
# The sentence "[...]" is a dialogue or a conversation between two or more people. It consists of a question and an answer, where the question is asked in the form of an interrogative sentence and the answer is given in the form of a declarative sentence. Specifically, the question is an interrogative sentence, and the answer is a declarative sentence.
#
#
# ####
# Why was the student cold? Because it was winter.
# The first sentence, "Why was the student cold?" is an interrogative sentence, as it is asking a question.
#
# The second sentence, "Because it was winter," is a declarative sentence, as it is making a statement.
#
#
# ####
# Why did the coworker burn his tongue? He drank his coffee too hot.
# The sentence is a simple declarative sentence. It presents a fact or statement about an event - the coworker burned his tongue because he drank his coffee too hot.
#
#
# ####
# Why don't millionaires give to charity? Because they're selfish.
# The first sentence is an interrogative sentence, also known as a question. The second sentence is a declarative sentence, which provides an answer to the question asked in the first sentence.
#
#
# ####
# Why did the man go to the doctor? Because it had a virus.
# The sentence "[...]" is an example of a sentence with a grammatical error. The second part of the sentence is incomplete and does not provide a direct answer to the question posed in the first part of the sentence.
#
# A corrected version of the sentence could be: "Why did the man go to the doctor? Because he was feeling ill and suspected he had a virus."
#
# This corrected sentence is a complex sentence consisting of two clauses, with the first clause being the independent clause ("Why did the man go to the doctor?") and the second clause being the dependent clause ("Because he was feeling ill and suspected he had a virus.").
#
#
# ####
# Why did the teacher go to the doctor? Because it wasn't peeling well.
# The sentence "[...]" is a joke or a play on words, which is a type of humorous sentence. It is a pun, which relies on the double meaning of the word "peeling" - it can mean the skin of a fruit or vegetable being removed or it can mean feeling unwell or sick. The sentence is structured as a question and answer format, but the answer is unexpected and humorous.
#
#
# ####
# Why did the driver file a police report? Because it got robbed.
# The first sentence is an interrogative sentence because it asks a question: "Why did the driver file a police report?"
#
# The second sentence is a declarative sentence because it makes a statement: "Because it got robbed."
#
#
# ####
# Why did the athlete bring two pairs of pants? In case one gets dirty.
# The sentence "[...]" is a dialogue or a conversation between two people where one person is asking a question and the other person is answering it. The first sentence is a question and the second sentence is the answer. Therefore, it is an example of a question and answer sentence.
#
#
# ####
# Why did the man put his money in the freezer? To hide it from intruders.
# The first sentence "Why did the man put his money in the freezer?" is an interrogative sentence, as it is asking a question.
#
# The second sentence "To hide it from intruders" is a declarative sentence, as it is making a statement.
#
#
# ####
# Why don't pigeon fly over the bay? Because they mostly live in cities.
# The given text contains two sentences.
#
# The first sentence is an interrogative sentence: "Why don't pigeon fly over the bay?" It is a type of sentence that asks a question and typically ends with a question mark.
#
# The second sentence is a declarative sentence: "Because they mostly live in cities." It is a type of sentence that makes a statement or expresses an opinion and typically ends with a period.
#
#
# ####
# Why did the daughter go to the seance? To talk to her mother.
# The given sentence is a dialogue or a conversation between two people, and it consists of two sentences:
#
# 1. A question: "Why did the daughter go to the seance?"
# 2. An answer: "To talk to her mother."
#
# So, the first sentence is an interrogative sentence (a question), and the second sentence is a declarative sentence (a statement that gives information).
#
#
# ####
# Why was the cashier sent to jail? Because she held up a dress.
# The first sentence is an interrogative sentence, which is a sentence that asks a question. The second sentence is a declarative sentence, which is a sentence that makes a statement or declares something.
#
#
# ####
# Why did the man cross the road? To get to the other side.
# The first sentence is an interrogative sentence, as it asks a question. The second sentence is a declarative sentence, as it makes a statement.
#
#
# ####
# Why did the man go to the doctor? Because he had a bite.
# The sentence "[...]" is a pair of sentences, where the first one is a question, and the second one is an answer or a subordinate clause. The first sentence is an interrogative sentence, which is a type of sentence used to ask a question. The second sentence is a declarative sentence, which is a type of sentence used to make a statement.
#
#
# ####
# Why did the astronaut go to outer space? To see the moon.
# The first sentence "Why did the astronaut go to outer space?" is an interrogative sentence because it asks a question.
#
# The second sentence "To see the moon" is a declarative sentence because it makes a statement.
#
#
# ####
# Why did the man put bananas in the blender? He wanted to make a smoothie.
# The first sentence is an interrogative sentence because it is asking a question. The second sentence is a declarative sentence because it is making a statement.
#
#
# ####
# Why don't schoolboys fight each other? They don't have the guts.
# The first sentence, "Why don't schoolboys fight each other?" is an interrogative sentence, as it is a question that seeks information or clarification.
#
# The second sentence, "They don't have the guts," is a declarative sentence, as it makes a statement.
#
#
# ####
# What do you call an man in a vest? A vest wearer.
# The sentence is a question followed by an answer. The question, "What do you call a man in a vest?" is an interrogative sentence, which is a type of sentence used to ask a question. The answer, "A vest wearer," is a declarative sentence, which is a type of sentence that makes a statement or declaration.

# %%
import pandas as pd
jokes = [
    "Why did the scarecrow win an award? Because he was outstanding in his field.",
    "Why did the tomato turn red? Because it saw the salad dressing.",
    "Why was the math book sad? Because it had too many problems.",
    "Why don't scientists trust atoms? Because they make up everything.",
    "Why did the cookie go to the doctor? Because it was feeling crumbly.",
    "Why couldn't the bicycle stand up by itself? Because it was two-tired.",
    "Why did the frog call his insurance company? He had a jump in his car.",
    "Why did the chicken cross the playground? To get to the other slide.",
    "Why was the computer cold? Because it left its Windows open.",
    "Why did the hipster burn his tongue? He drank his coffee before it was cool.",
    "Why don't oysters give to charity? Because they're shellfish.",
    "Why did the computer go to the doctor? Because it had a virus.",
    "Why did the banana go to the doctor? Because it wasn't peeling well.",
    "Why did the coffee file a police report? Because it got mugged.",
    "Why did the golfer bring two pairs of pants? In case he got a hole in one.",
    "Why did the man put his money in the freezer? He wanted cold hard cash.",
    "Why don't seagulls fly over the bay? Because then they'd be bagels.",
    "Why did the chicken go to the seance? To talk to the other side.",
    "Why was the belt sent to jail? Because it held up a pair of pants.",
    "Why did the chicken cross the road? To get to the other side.",
    "Why did the computer go to the doctor? Because it had a byte.",
    "Why did the cow go to outer space? To see the moooon.",
    "Why did the man put his money in the blender? He wanted to make liquid assets.",
    "Why don't skeletons fight each other? They don't have the guts.",
    "What do you call an alligator in a vest? An investigator.",
]

jokes_onesen = [
    "The scarecrow won an award because he was outstanding in his field.",
    "The tomato turned red because it saw the salad dressing.",
    "The math book was sad because it had too many problems.",
    "Scientists don't trust atoms because they make up everything.",
    "The cookie went to the doctor because it was feeling crumbly.",
    "The bicycle couldn't stand up by itself because it was two-tired.",
    "The frog called his insurance company because he had a jump in his car.",
    "The chicken crossed the playground to get to the other slide.",
    "The computer was cold because it left its Windows open.",
    "The hipster burned his tongue because he drank his coffee before it was cool.",
    "Oysters don't give to charity because they're shellfish.",
    "The computer went to the doctor because it had a virus.",
    "The banana went to the doctor because it wasn't peeling well.",
    "The coffee filed a police report because it got mugged.",
    "The golfer brings two pairs of pants in case he got a hole in one.",
    "The man put his money in the freezer because he wanted cold hard cash.",
    "Seagulls don't fly over the bay because then they'd be bagels.",
    "The chicken went to the seance to talk to the other side.",
    "The belt was sent to jail because it held up a pair of pants.",
    "The chicken crossed the road to get to the other side.",
    "The computer went to the doctor because it had a byte.",
    "The cow went to outer space to see the moooon.",
    "The man put his money in the blender because he wanted to make liquid assets.",
    "Skeletons don't fight each other because they don't have the guts.",
    "An alligator in a vest is called an investigator.",
]

noj1 = [ # without wordplay, but with picutre
    "Why did the scarecrow win an award? Because he did very good work.",
    "Why did the tomato turn red? Because it had a lot sun recently.",
    "Why was the math book sad? Because it was a rainy day.",
    "Why don't scientists trust atoms? Because they tend to lie.",
    "Why did the cookie go to the doctor? Because it was feeling unwell.",
    "Why couldn't the bicycle stand up by itself? Because it didn't have racks.",
    "Why did the frog call his insurance company? He had a scratch in his car.",
    #"Why did the oyster cross the playground? To get to the other slide.", ###
    "Why was the computer cold? Because the heater was broken.",
    "Why did the hipster burn his tongue? He drank hot coffee.",
    "Why don't oysters give to charity? Because they have no money.",
    "Why did the computer go to the doctor? Because it was sick.",
    "Why did the banana go to the doctor? Because it was sick.",
    "Why did the coffee file a police report? Because it got robbed.",
    "Why did the golfer bring two pairs of pants? In case one gets damaged.", ###
    # "Why did the man put his money in the freezer? He wanted cold hard cash.",
    "Why don't seagulls fly over the bay? Because they are mostly living in ports.",
    #"Why did the chicken go to the seance? To talk to the other side.",
    "Why was the belt sent to jail? Because it stole in a store.",
   # "Why did the chicken cross the road? To get to the other side.",
    "Why did the computer go to the doctor? Because it had a headache.",
    "Why did the chicken go to outer space? To see the moon.",
   # "Why did the man put bananas in the blender? He wanted to make liquid assets.",
    "Why don't skeletons fight each other? They are dead already.",
    "What do you call an alligator in a pullpver? A clothed alligator.",
]

noj2 = [ # without picture
    "Why did the scientist win an award? Because he did very good work.",
    "Why did the man turn red? Because he saw the neighbour dressing.",#"Why did the tomato turn red? Because it saw the salad dressing.",
    "Why was the child sad? Because it had many problems.",
    "Why don't scientists trust journalists? Because they make up everything.",
    "Why did the woman go to the doctor? Because she was feeling crumbly.",
    "Why couldn't the man stand up by itself? Because he was drunk.",
    "Why did the driver call his insurance company? He had a jump in his car.",
    "Why did the kid cross the playground? To get to the other slide.",
    "Why was the student cold? Because it was winter.",
    "Why did the coworker burn his tongue? He drank his coffee too hot.",
    "Why don't millionaires give to charity? Because they're selfish.",
    "Why did the man go to the doctor? Because he had a virus.",
    "Why did the teacher go to the doctor? Because it wasn't peeling well.",
    "Why did the driver file a police report? Because it got robbed.",
    "Why did the athlete bring two pairs of pants? In case one gets dirty.",
    "Why did the man put his money in the freezer? To hide it from intruders.",
    "Why don't pigeon fly over the bay? Because they mostly live in cities.",
    "Why did the daughter go to the seance? To talk to her mother.",
    "Why was the cashier sent to jail? Because she held up a dress.",
    "Why did the man cross the road? To get to the other side.",
    "Why did the man go to the doctor? Because he had a bite.",
    "Why did the astronaut go to outer space? To see the moon.",
    "Why did the man put bananas in the blender? He wanted to make a smoothie.", 
    "Why don't schoolboys fight each other? They don't have the guts.",
    "What do you call an man in a vest? A vest wearer.", 
]

alldf = pd.read_pickle("joke_detection_newnew")
all = jokes + jokes_onesen + noj1 + noj2
print(len(all))
print(alldf.shape)

import collections
print([item for item, count in collections.Counter(all).items() if count > 1])
# Out:
# 95
# (95, 2)
# []

# %%
# newnew
import pandas as pd
jokes = [
    "Why did the scarecrow win an award? Because he was outstanding in his field.",
    "Why did the tomato turn red? Because it saw the salad dressing.",
    "Why was the math book sad? Because it had too many problems.",
    "Why don't scientists trust atoms? Because they make up everything.",
    "Why did the cookie go to the doctor? Because it was feeling crumbly.",
    "Why couldn't the bicycle stand up by itself? Because it was two-tired.",
    "Why did the frog call his insurance company? He had a jump in his car.",
    "Why did the chicken cross the playground? To get to the other slide.",
    "Why was the computer cold? Because it left its Windows open.",
    "Why did the hipster burn his tongue? He drank his coffee before it was cool.",
    "Why don't oysters give to charity? Because they're shellfish.",
    "Why did the computer go to the doctor? Because it had a virus.",
    "Why did the banana go to the doctor? Because it wasn't peeling well.",
    "Why did the coffee file a police report? Because it got mugged.",
    "Why did the golfer bring two pairs of pants? In case he got a hole in one.",
    "Why did the man put his money in the freezer? He wanted cold hard cash.",
    "Why don't seagulls fly over the bay? Because then they'd be bagels.",
    "Why did the chicken go to the seance? To talk to the other side.",
    "Why was the belt sent to jail? Because it held up a pair of pants.",
    "Why did the chicken cross the road? To get to the other side.",
    "Why did the computer go to the doctor? Because it had a byte.",
    "Why did the cow go to outer space? To see the moooon.",
    "Why did the man put his money in the blender? He wanted to make liquid assets.",
    "Why don't skeletons fight each other? They don't have the guts.",
    "What do you call an alligator in a vest? An investigator.",
]

jokes_onesen = [
    "The scarecrow won an award because he was outstanding in his field.",
    "The tomato turned red because it saw the salad dressing.",
    "The math book was sad because it had too many problems.",
    "Scientists don't trust atoms because they make up everything.",
    "The cookie went to the doctor because it was feeling crumbly.",
    "The bicycle couldn't stand up by itself because it was two-tired.",
    "The frog called his insurance company because he had a jump in his car.",
    "The chicken crossed the playground to get to the other slide.",
    "The computer was cold because it left its Windows open.",
    "The hipster burned his tongue because he drank his coffee before it was cool.",
    "Oysters don't give to charity because they're shellfish.",
    "The computer went to the doctor because it had a virus.",
    "The banana went to the doctor because it wasn't peeling well.",
    "The coffee filed a police report because it got mugged.",
    "The golfer brings two pairs of pants in case he got a hole in one.",
    "The man put his money in the freezer because he wanted cold hard cash.",
    "Seagulls don't fly over the bay because then they'd be bagels.",
    "The chicken went to the seance to talk to the other side.",
    "The belt was sent to jail because it held up a pair of pants.",
    "The chicken crossed the road to get to the other side.",
    "The computer went to the doctor because it had a byte.",
    "The cow went to outer space to see the moooon.",
    "The man put his money in the blender because he wanted to make liquid assets.",
    "Skeletons don't fight each other because they don't have the guts.",
    "An alligator in a vest is called an investigator.",
]

noj1 = [ # without wordplay, but with picutre
    "Why did the scarecrow win an award? Because he did very good work.",
    "Why did the tomato turn red? Because it had a lot sun recently.",
    "Why was the math book sad? Because it was a rainy day.",
    "Why don't scientists trust atoms? Because they tend to lie.",
    "Why did the cookie go to the doctor? Because it was feeling unwell.",
    "Why couldn't the bicycle stand up by itself? Because it didn't have racks.",
    "Why did the frog call his insurance company? He had a scratch in his car.",
    #"Why did the oyster cross the playground? To get to the other slide.", ###
    "Why was the computer cold? Because the heater was broken.",
    "Why did the hipster burn his tongue? He drank hot coffee.",
    "Why don't oysters give to charity? Because they have no money.",
    "Why did the computer go to the doctor? Because it was sick.",
    "Why did the banana go to the doctor? Because it was sick.",
    "Why did the coffee file a police report? Because it got robbed.",
    "Why did the golfer bring two pairs of pants? In case one gets damaged.", ###
    # "Why did the man put his money in the freezer? He wanted cold hard cash.",
    "Why don't seagulls fly over the bay? Because they are mostly living in ports.",
    #"Why did the chicken go to the seance? To talk to the other side.",
    "Why was the belt sent to jail? Because it stole in a store.",
   # "Why did the chicken cross the road? To get to the other side.",
    "Why did the computer go to the doctor? Because it had a headache.",
    "Why did the chicken go to outer space? To see the moon.",
   # "Why did the man put bananas in the blender? He wanted to make liquid assets.",
    "Why don't skeletons fight each other? They are dead already.",
    "What do you call an alligator in a pullpver? A clothed alligator.",
]

noj2 = [ # without picture
    "Why did the scientist win an award? Because he did very good work.",
    "Why did the man turn red? Because he saw the neighbour dressing.",#"Why did the tomato turn red? Because it saw the salad dressing.",
    "Why was the child sad? Because it had many problems.",
    "Why don't scientists trust journalists? Because they make up everything.",
    "Why did the woman go to the doctor? Because she was feeling crumbly.",
    "Why couldn't the man stand up by itself? Because he was drunk.",
    "Why did the driver call his insurance company? He had a jump in his car.",
    "Why did the kid cross the playground? To get to the other slide.",
    "Why was the student cold? Because it was winter.",
    "Why did the coworker burn his tongue? He drank his coffee too hot.",
    "Why don't millionaires give to charity? Because they're selfish.",
    "Why did the man go to the doctor? Because he had a virus.",
    "Why did the teacher go to the doctor? Because it wasn't peeling well.",
    "Why did the driver file a police report? Because it got robbed.",
    "Why did the athlete bring two pairs of pants? In case one gets dirty.",
    "Why did the man put his money in the freezer? To hide it from intruders.",
    "Why don't pigeon fly over the bay? Because they mostly live in cities.",
    "Why did the daughter go to the seance? To talk to her mother.",
    "Why was the cashier sent to jail? Because she held up a dress.",
    "Why did the man cross the road? To get to the other side.",
    "Why did the man go to the doctor? Because he had a bite.",
    "Why did the astronaut go to outer space? To see the moon.",
    "Why did the man put bananas in the blender? He wanted to make a smoothie.", 
    "Why don't schoolboys fight each other? They don't have the guts.",
    "What do you call an man in a vest? A vest wearer.", 
]


alldf = pd.read_pickle("joke_detection_newnew")


for i in range(alldf.shape[0] ): 
    try: 
        df.iloc[i,1] = df.iloc[i,1]['message']
        df.iloc[i,0] = df.iloc[i,0].replace('What kind of sentence is that: ', "")
        df.iloc[i,1] = df.iloc[i,1].replace(df.iloc[i,0], "[...]")
    #df.iloc[i,1] = df.iloc[i,1].replace('"[...]"', "[...]")
    except:
        None
def done():

    for i in range(df.shape[0] ):
        print('####')
        print(df.iloc[i,0])
        print(df.iloc[i,1])


all = jokes + jokes_onesen + noj1 + noj2
alls = list(set(all))
print 
#all.sort()
#alls.sort()

# alldf = pd.read_pickle("joke_detection_newnew")

# here i sort the responses. i randomised the order for scientific reasons
sortid = []
for elem in alldf.prompt.tolist():
    for i in range(len(all)):
        if all[i] in elem:
            #print(i, elem)
            sortid.append(i)

alldf = alldf.reset_index(drop=True)
#alldf.drop("index", axis=1)

alldf['position'] = sortid
alldf = alldf.set_index('position')

alldf = alldf.sort_index()


for i in range(alldf.shape[0] ):
    print('####')
    print(alldf.iloc[i,0])
    print(alldf.iloc[i,1])
# Out:
# ####
# What kind of sentence is that: Why did the scarecrow win an award? Because he was outstanding in his field.
# {'message': 'This is a joke or pun that plays on the multiple meanings of the phrase "outstanding in his field". The first sentence is an interrogative sentence, or a question, asking why the scarecrow won an award. The second sentence is a declarative sentence, providing the answer to the question with a play on words, suggesting that the scarecrow won the award because he was excellent in his field of work (i.e., standing in a field as a scarecrow) and outstanding in his particular field (i.e., standing out or excelling among other scarecrows).\n\n', 'conversation_id': '9874589c-c985-408e-a0b3-2d23770669be'}
# ####
# What kind of sentence is that: Why did the tomato turn red? Because it saw the salad dressing.
# {'message': 'The sentence "Why did the tomato turn red? Because it saw the salad dressing." is a joke or a pun, and not a typical sentence. It plays on the literal and figurative meanings of "seeing red" and the idea that the tomato "saw" the salad dressing, which caused it to turn red. As a result, it is not a sentence that would be commonly used in everyday speech or writing, but rather a humorous play on words.\n\n', 'conversation_id': '1c2c0b93-6afe-48ef-9418-99659c021f4a'}
# ####
# What kind of sentence is that: Why was the math book sad? Because it had too many problems.
# {'message': 'The sentence "Why was the math book sad? Because it had too many problems" is a joke or a riddle. It\'s a play on words, using the word "problems" in two different senses: as mathematical exercises that need to be solved, and as difficulties or challenges that cause sadness or distress. This type of sentence is often used to create humor or to challenge the listener/reader to think creatively.\n\n', 'conversation_id': '1aef66dd-7d02-4480-a39c-75c65c26b096'}
# ####
# What kind of sentence is that: Why don't scientists trust atoms? Because they make up everything.
# {'message': 'The sentence is a joke, or a play on words, that relies on a pun. It is a combination of a question and an answer that uses wordplay to create humor. In terms of grammatical structure, the first part of the sentence is an interrogative sentence, or a question, and the second part is a declarative sentence, or a statement.\n\n', 'conversation_id': '00c5f904-0982-47ba-9695-fe23bf9d03d9'}
# ####
# What kind of sentence is that: Why did the cookie go to the doctor? Because it was feeling crumbly.
# {'message': 'The sentence "Why did the cookie go to the doctor? Because it was feeling crumbly" is a joke or a riddle. It\'s not a typical declarative sentence that makes a statement or provides information. Instead, it\'s meant to be humorous and play on words by using a pun.\n\n', 'conversation_id': '8715e5f9-aab3-4612-9a43-cdc727b41cb6'}
# ####
# What kind of sentence is that: Why couldn't the bicycle stand up by itself? Because it was two-tired.
# {'message': 'The sentence is a joke or a pun. It consists of a question followed by a punchline that plays on the words "two-tired" which sounds like "too tired." The sentence does not fit into any specific grammatical category but it is a type of wordplay used for humorous effect.\n\n', 'conversation_id': 'fa0400c3-0214-4b45-9c7f-7419cf9093fb'}
# ####
# What kind of sentence is that: Why did the frog call his insurance company? He had a jump in his car.
# {'message': 'This is a pun or play on words. The sentence plays on the double meaning of "jump" as both a type of movement and a malfunction in a car\'s battery. The sentence can also be classified as a joke or a riddle.\n\n', 'conversation_id': 'b5efb9da-df52-401e-9bb3-1fb4963eab11'}
# ####
# What kind of sentence is that: Why did the chicken cross the playground? To get to the other slide.
# {'message': 'The sentence is a joke or a riddle. It is a type of question that is asked to prompt a humorous or unexpected answer.\n\n', 'conversation_id': '43a23296-3905-4f12-bb3c-112638bf8530'}
# ####
# What kind of sentence is that: Why was the computer cold? Because it left its Windows open.
# {'message': 'The sentence "Why was the computer cold? Because it left its Windows open." is a pun, which is a play on words that exploits multiple meanings of a term, or similar-sounding words, for a humorous or rhetorical effect. In this case, the pun is based on the double meaning of the word "Windows," which refers to both the operating system developed by Microsoft and the physical windows on a computer.\n\n', 'conversation_id': '386ac08b-70d1-4eaf-8232-253c4d0bad92'}
# ####
# What kind of sentence is that: Why did the hipster burn his tongue? He drank his coffee before it was cool.
# {'message': 'The sentence "Why did the hipster burn his tongue? He drank his coffee before it was cool." is a joke, but grammatically it is a compound sentence composed of two independent clauses joined by the conjunction "and".\n\n', 'conversation_id': '5163f37f-cc29-423f-87f2-b0bb27f99293'}
# ####
# What kind of sentence is that: Why don't oysters give to charity? Because they're shellfish.
# {'message': 'The sentence is a play on words and uses a pun. It is a humorous response to the question "Why don\'t oysters give to charity?" The answer "Because they\'re shellfish" is a pun on the word "selfish," which means concerned primarily with one\'s own interests or welfare, and "shellfish," which refers to a type of seafood with a shell. This type of sentence is called a pun or a joke.\n\n', 'conversation_id': '1965beb6-659f-4659-9e60-c825b0876a6d'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a virus.
# {'message': 'The first sentence "Why did the computer go to the doctor?" is an interrogative sentence, which is used to ask a question.\n\nThe second sentence "Because it had a virus" is a declarative sentence, which is used to make a statement or express a fact. It provides an answer to the question asked in the first sentence.\n\n', 'conversation_id': '21fc1201-b3d9-45d2-af1f-7a2442fad2bb'}
# ####
# What kind of sentence is that: Why did the banana go to the doctor? Because it wasn't peeling well.
# {'message': 'The given sentence is a joke or a pun. It uses a play on words by using the phrase "peeling well" instead of "feeling well" to create a humorous effect.\n\n', 'conversation_id': 'a614346f-43f5-45fc-9187-0deb57f4d294'}
# ####
# What kind of sentence is that: Why did the coffee file a police report? Because it got mugged.
# {'message': 'The sentence is a play on words and consists of two parts: a question and an answer.\n\nThe first part of the sentence is a question that starts with the word "why." This indicates that the sentence is an interrogative sentence, meaning it is designed to ask a question.\n\nThe second part of the sentence is an answer to the question posed in the first part. It is a pun or a play on words, where the word "mugged" is used to describe what happened to the coffee. This part of the sentence is a declarative sentence, meaning it is a statement that declares something.\n\n', 'conversation_id': '11dcc515-6148-4760-b0b3-af1e039f84e9'}
# ####
# What kind of sentence is that: Why did the golfer bring two pairs of pants? In case he got a hole in one.
# {'message': 'The sentence is a play on words and can be classified as a joke or a pun. It contains a question that sets up an expectation for a serious answer, but the punchline turns the question into a humorous twist.\n\n', 'conversation_id': '323219c5-fc30-4f46-b3fa-64399b98756a'}
# ####
# What kind of sentence is that: Why did the man put his money in the freezer? He wanted cold hard cash.
# {'message': 'The sentence is a joke or pun that plays on the double meaning of the phrase "cold hard cash." It starts with a question, "Why did the man put his money in the freezer?" and ends with a punchline or answer, "He wanted cold hard cash."\n\nIn terms of sentence structure, it is a simple declarative sentence.\n\n', 'conversation_id': '85116b08-28e0-40b9-abe7-f5a7fb153686'}
# ####
# What kind of sentence is that: Why don't seagulls fly over the bay? Because then they'd be bagels.
# {'message': 'The sentence is a play on words and is a joke, which makes it a type of declarative sentence called a "pun." Specifically, it is a play on the words "seagulls" and "bagels," which sound similar but have very different meanings. The sentence is structured as a conditional statement, with the first part posing a hypothetical question, and the second part providing a humorous answer to that question.\n\n', 'conversation_id': '2a29df43-b22f-4953-b5b3-521327b10663'}
# ####
# What kind of sentence is that: Why did the chicken go to the seance? To talk to the other side.
# {'message': 'The sentence is a joke, specifically a pun. It uses a play on words with the phrase "talk to the other side," which can mean both communicating with the dead in a séance and simply crossing to the other side of a physical space. Therefore, the sentence is not a standard declarative, interrogative, imperative, or exclamatory sentence, but rather a humorous statement that relies on the use of language in a creative way.\n\n', 'conversation_id': 'b6864734-9471-4c10-9cbf-b12336f2e35b'}
# ####
# What kind of sentence is that: Why was the belt sent to jail? Because it held up a pair of pants.
# {'message': 'The sentence "Why was the belt sent to jail? Because it held up a pair of pants." is a joke or a pun, as it relies on a play on words. It is a type of sentence called a "riddle" or a "puzzle," which is meant to be amusing or thought-provoking.\n\n', 'conversation_id': 'ac53ad2d-cfce-4112-9afe-e7716d6a2d3d'}
# ####
# What kind of sentence is that: Why did the chicken cross the road? To get to the other side.
# {'message': 'The first sentence, "Why did the chicken cross the road?", is an interrogative sentence because it asks a question.\n\nThe second sentence, "To get to the other side," is a declarative sentence because it makes a statement.\n\n', 'conversation_id': '4e415abb-71d0-461b-bef0-bb2be72c5cd2'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a byte.
# {'message': 'The sentence is a joke, but grammatically it is a question followed by an answer. The question is "Why did the computer go to the doctor?" and the answer is "Because it had a byte."\n\n', 'conversation_id': '1111f2df-c2c6-412e-a8d9-0ecc1c24a4ff'}
# ####
# What kind of sentence is that: Why did the cow go to outer space? To see the moooon.
# {'message': 'The sentence is a joke, consisting of two parts: a question and a punchline. The question "Why did the cow go to outer space?" is an interrogative sentence, and the punchline "To see the moooon." is a declarative sentence.\n\n', 'conversation_id': '74018045-8df3-405b-aaf6-b68f20abb4aa'}
# ####
# What kind of sentence is that: Why did the man put his money in the blender? He wanted to make liquid assets.
# {'message': 'The sentence is a joke or pun that uses a play on words. The first sentence is a question that sets up the joke, while the second sentence delivers the punchline.\n\n', 'conversation_id': '2e0762d3-b12a-48af-9140-fc9dbe828735'}
# ####
# What kind of sentence is that: Why don't skeletons fight each other? They don't have the guts.
# {'message': 'The sentence is a pun, which is a type of word play that exploits multiple meanings of a term or phrase, or similar-sounding words with different meanings, for humorous or rhetorical effect. In this case, the sentence is a play on the double meaning of "guts", which can refer to both courage and the internal organs of a person or animal. The sentence is a play on the idea that skeletons don\'t have guts in the sense of internal organs, but also don\'t have the courage to fight each other.\n\n', 'conversation_id': '6eef7127-2939-4e81-8e7d-307457734860'}
# ####
# What kind of sentence is that: What do you call an alligator in a vest? An investigator.
# {'message': 'The sentence "What do you call an alligator in a vest? An investigator." is a riddle, which is a type of question that is posed as a puzzle or a game and is meant to be solved or answered by the listener or reader. In this case, the sentence is a play on words, using the words "alligator" and "investigator" to create a pun.\n\n', 'conversation_id': '8bff4972-9b1b-4f70-a25c-9956b8747313'}
# ####
# What kind of sentence is that: The scarecrow won an award because he was outstanding in his field.
# {'message': 'This sentence is a pun. It uses wordplay by using the phrase "outstanding in his field" to describe the scarecrow\'s excellence as both being outstanding within his area of expertise (as in a professional field) and literally outstanding in a field as a scarecrow standing out among crops. The sentence can also be classified as a declarative sentence since it makes a statement.\n\n', 'conversation_id': 'f9a82aac-afad-4f02-bd0e-700a9d5f0165'}
# ####
# What kind of sentence is that: The tomato turned red because it saw the salad dressing.
# {'message': 'The sentence "The tomato turned red because it saw the salad dressing" is an example of an incorrect sentence or a nonstandard sentence. This sentence uses personification by giving human characteristics to non-human things like the tomato and the salad dressing. In reality, a tomato cannot see anything because it does not have eyes, and it does not turn red because of the salad dressing. A corrected version of the sentence could be "The tomato turned red because of a natural ripening process, not because it saw the salad dressing."\n\n', 'conversation_id': '2c248e03-1734-4f29-8f4d-fda72b2ead12'}
# ####
# What kind of sentence is that: The math book was sad because it had too many problems.
# {'message': 'The sentence "The math book was sad because it had too many problems" is a simple sentence. It consists of one independent clause that contains a subject ("math book") and a predicate ("was sad because it had too many problems"). The sentence expresses a complete thought and can stand alone as a complete sentence.\n\n', 'conversation_id': 'd1610862-0b53-458e-9bd4-670132ed504f'}
# ####
# What kind of sentence is that: Scientists don't trust atoms because they make up everything.
# {'message': 'The sentence "Scientists don\'t trust atoms because they make up everything" is a humorous and ironic statement that plays on the multiple meanings of the phrase "make up". It is not a literal or factual statement about how scientists view atoms, but rather a play on words. From a grammatical standpoint, it is a simple declarative sentence, with the subject "Scientists" and the predicate "don\'t trust atoms because they make up everything".\n\n', 'conversation_id': '9666fed3-d677-47a0-bc5f-34b192d0cdaa'}
# ####
# What kind of sentence is that: The cookie went to the doctor because it was feeling crumbly.
# {'message': 'The sentence "The cookie went to the doctor because it was feeling crumbly" is a simple declarative sentence. It contains a subject ("the cookie") and a predicate ("went to the doctor because it was feeling crumbly") that expresses a complete thought.\n\n', 'conversation_id': 'b40c7801-bb94-44b5-b2e8-14e7f0306bbf'}
# ####
# What kind of sentence is that: The bicycle couldn't stand up by itself because it was two-tired.
# {'message': 'The sentence is a pun, which is a type of wordplay that exploits multiple meanings of a term or similar-sounding words for humorous or rhetorical effect. It has a play on words between "two-tired" (meaning having two wheels) and "too tired" (meaning exhausted). The sentence also functions as a declarative sentence, conveying information about the bicycle\'s inability to stand up on its own.\n\n', 'conversation_id': 'e3159c5a-5322-48aa-951b-2fb79df4b6fd'}
# ####
# What kind of sentence is that: The frog called his insurance company because he had a jump in his car.
# {'message': 'The sentence is a pun, playing with the different meanings of the word "jump." Grammatically, it is a declarative sentence in the past tense.\n\n', 'conversation_id': '7f386bbc-534b-44f3-aa61-11ec91613e9c'}
# ####
# What kind of sentence is that: The chicken crossed the playground to get to the other slide.
# {'message': 'The sentence "The chicken crossed the playground to get to the other slide." is a simple declarative sentence. It contains a subject "the chicken" and a predicate "crossed the playground to get to the other slide." The sentence presents a statement or fact about what the chicken did, without posing a question or expressing a command or strong emotion.\n\n', 'conversation_id': 'faf1ba87-3d05-4d1c-9cab-d8e7a49deb94'}
# ####
# What kind of sentence is that: The computer was cold because it left its Windows open.
# {'message': 'The sentence "The computer was cold because it left its Windows open" is a simple declarative sentence. It consists of a subject "The computer", a verb "was", and a predicate that includes an adjective "cold" and a dependent clause "because it left its Windows open".\n\n', 'conversation_id': '929a9a25-22f8-499e-86b6-30c003a861c3'}
# ####
# What kind of sentence is that: The hipster burned his tongue because he drank his coffee before it was cool.
# {'message': 'The sentence "The hipster burned his tongue because he drank his coffee before it was cool" is a simple declarative sentence. It expresses a complete thought and makes a statement that can be either true or false.\n\n', 'conversation_id': '624a09f0-4830-4c9c-b07d-da1875815aab'}
# ####
# What kind of sentence is that: Oysters don't give to charity because they're shellfish.
# {'message': 'The sentence "Oysters don\'t give to charity because they\'re shellfish" is a pun or play on words, based on the double meaning of the word "shellfish." The sentence is a declarative sentence, which makes a statement about oysters and their charitable giving habits, but it is also a humorous sentence because it uses a pun to play with the word "shellfish" and its two meanings: (1) an aquatic animal with a shell, and (2) a person who is selfish.\n\n', 'conversation_id': '45aa95f6-8673-4b25-b8e8-dc9f7c465d80'}
# ####
# What kind of sentence is that: The computer went to the doctor because it had a virus.
# {'message': 'The type of sentence is a simple declarative sentence. It presents a statement or fact and ends with a period.\n\n', 'conversation_id': '565ce09b-61ba-427f-89df-7c3cf59ea659'}
# ####
# What kind of sentence is that: The banana went to the doctor because it wasn't peeling well.
# {'message': 'The given sentence is a simple declarative sentence. It makes a statement or assertion about the banana and its action of going to the doctor due to its inability to peel well.\n\n', 'conversation_id': '6db23a4d-89e4-448b-8dc3-e13d22a3a30e'}
# ####
# What kind of sentence is that: The coffee filed a police report because it got mugged.
# {'message': 'The sentence is a humorous or playful one, as it uses personification to give human-like qualities to a non-human object (coffee) and creates an absurd scenario where the coffee is the victim of a mugging and files a police report. However, grammatically, the sentence is a declarative sentence because it makes a statement.\n\n', 'conversation_id': 'a8131a73-9c5e-4098-a4b6-c3f9f28e6606'}
# ####
# What kind of sentence is that: The golfer brings two pairs of pants in case he got a hole in one.
# {'message': 'The sentence "The golfer brings two pairs of pants in case he got a hole in one" is a simple declarative sentence in the present tense.\n\n', 'conversation_id': 'ba31632d-f4c6-4f5f-b9e4-101f7342c444'}
# ####
# What kind of sentence is that: The man put his money in the freezer because he wanted cold hard cash.
# {'message': 'The type of sentence is a simple declarative sentence.\n\n', 'conversation_id': 'db38baee-809b-41c1-9296-fc3dc7c07905'}
# ####
# What kind of sentence is that: Seagulls don't fly over the bay because then they'd be bagels.
# {'message': 'The sentence "Seagulls don\'t fly over the bay because then they\'d be bagels" is a humorous statement or a joke. It is not a serious statement, as seagulls cannot actually become bagels by flying over the bay. This sentence uses a pun or a play on words, as the words "bay" and "bagels" sound similar.\n\n', 'conversation_id': '0a9ef5f4-9a79-41dc-9167-0061cc082ab9'}
# ####
# What kind of sentence is that: The chicken went to the seance to talk to the other side.
# {'message': 'The sentence is a grammatically correct declarative sentence. However, the content of the sentence contains a nonsensical or absurd statement as chickens are not capable of attending seances or communicating with the dead.\n\n', 'conversation_id': '4d8de964-94f4-4348-ac54-fd74a7cf1fbc'}
# ####
# What kind of sentence is that: The belt was sent to jail because it held up a pair of pants.
# {'message': 'The sentence is an example of personification, which is a literary device that gives human qualities to non-human things or abstract concepts. In this case, the belt is personified as if it were a person who committed a crime (holding up a pair of pants) and was sent to jail as a punishment.\n\n', 'conversation_id': '79b603b7-1a95-4d38-82f9-d25123b18c74'}
# ####
# What kind of sentence is that: The chicken crossed the road to get to the other side.
# {'message': 'The sentence "The chicken crossed the road to get to the other side" is a simple declarative sentence. It states a fact or makes a statement without posing a question or issuing a command. Specifically, it describes an action taken by a chicken to cross a road in order to reach the opposite side.\n\n', 'conversation_id': '90412224-04e2-4a6a-b9bf-fd8e1786f013'}
# ####
# What kind of sentence is that: The computer went to the doctor because it had a byte.
# {'message': 'The sentence is a play on words and is an example of a pun. It uses the homophones "byte" and "bite" to create a humorous sentence. Structurally, it is a simple declarative sentence in the past tense, with the subject "computer" and the predicate "went to the doctor because it had a byte."\n\n', 'conversation_id': 'd83d8a16-b3f6-4b80-92c8-d4e92ad6229c'}
# ####
# What kind of sentence is that: The cow went to outer space to see the moooon.
# {'message': 'The given sentence is a declarative sentence.\n\n', 'conversation_id': '838a81c2-3290-4b01-944c-1e6f08889da4'}
# ####
# What kind of sentence is that: The man put his money in the blender because he wanted to make liquid assets.
# {'message': 'The sentence is a play on words that uses a pun. Grammatically, it is a declarative sentence, which makes a statement or assertion.\n\n', 'conversation_id': '4d55a509-c626-4a94-8692-7ca0641863be'}
# ####
# What kind of sentence is that: Skeletons don't fight each other because they don't have the guts.
# {'message': 'The sentence "Skeletons don\'t fight each other because they don\'t have the guts" is a pun, as it uses a play on words to create a humorous effect. The pun relies on the dual meanings of the phrase "having the guts." In one sense, it means having the courage or fortitude to do something, while in another sense, it refers to the literal guts or intestines that skeletons don\'t have. Therefore, the sentence can be classified as a declarative sentence that uses wordplay to create a pun.\n\n', 'conversation_id': 'fa012e20-8b25-4748-80a9-5d16ccacd80b'}
# ####
# What kind of sentence is that: An alligator in a vest is called an investigator.
# {'message': 'The sentence "An alligator in a vest is called an investigator" is a play on words, specifically a pun. It is not a sentence that fits into a particular category of grammatical or syntactical structure. Instead, it relies on the similarity in sound between the words "alligator" and "investigator" to create a humorous effect.\n\n', 'conversation_id': '521c78dd-2f47-427a-b769-cbedabb33496'}
# ####
# What kind of sentence is that: Why did the scarecrow win an award? Because he did very good work.
# {'message': 'The given sentence is a dialogue consisting of two sentences, a question and an answer.\n\nThe first sentence is an interrogative sentence, as it begins with the interrogative word "why" and is seeking information.\n\nThe second sentence is a declarative sentence, as it provides information and makes a statement about the reason for the scarecrow winning an award.\n\n', 'conversation_id': '161841e6-2627-4f65-ae26-46ddf69ec745'}
# ####
# What kind of sentence is that: Why did the tomato turn red? Because it had a lot sun recently.
# {'message': 'The given sentence is a complex sentence as it consists of one independent clause and one dependent clause.\n\nThe independent clause is "Why did the tomato turn red?" which can stand alone as a complete sentence.\n\nThe dependent clause is "Because it had a lot of sun recently" which cannot stand alone as a complete sentence because it does not express a complete thought. It is dependent on the independent clause for its meaning.\n\n', 'conversation_id': '8acf4a18-a43e-4b3b-8a1b-c2c72a57c59f'}
# ####
# What kind of sentence is that: Why was the math book sad? Because it was a rainy day.
# {'message': 'The sentence "Why was the math book sad? Because it was a rainy day." is a joke or a riddle. It is not a complete sentence on its own, as it lacks a subject-verb predicate structure. However, it is intended to be a play on words, using the concept of personification (attributing human qualities to non-human things) to create humor.\n\n', 'conversation_id': '7eba5bc5-ecbc-48c2-9836-b86fbaea0e5d'}
# ####
# What kind of sentence is that: Why don't scientists trust atoms? Because they tend to lie.
# {'message': 'The sentence "Why don\'t scientists trust atoms? Because they tend to lie." is a joke or a play on words. It is not meant to be taken seriously as a scientific statement. Instead, it is a humorous way of playing with the double meaning of the word "lie" which can mean both "to lie down" and "to tell a falsehood". In this context, the sentence is a pun, as the word "lie" is used to mean "to lie down", which is something that atoms do tend to do. However, the joke is that the sentence is phrased in a way that suggests the word "lie" is being used to mean "to tell a falsehood", which is a completely different meaning.\n\n', 'conversation_id': '550ad3b5-e523-4ce5-8594-8b08bca44670'}
# ####
# What kind of sentence is that: Why did the cookie go to the doctor? Because it was feeling unwell.
# {'message': 'The sentence "Why did the cookie go to the doctor? Because it was feeling unwell." is a joke or riddle. It\'s a play on words where the answer is unexpected or humorous.\n\n', 'conversation_id': '00ef06a4-56ac-4c2e-954d-4fd603b9fb81'}
# ####
# What kind of sentence is that: Why couldn't the bicycle stand up by itself? Because it didn't have racks.
# {'message': 'The sentence is a joke or a riddle. It is a question and answer format, where the question sets up an expectation for a serious or meaningful answer, but the answer delivers a pun or a play on words. Specifically, this joke plays with the double meaning of the word "racks," which can refer to either a bicycle rack (a device used to store or transport bicycles) or the ability of a person or object to stand upright.\n\n', 'conversation_id': '12d4e560-a25f-46c8-b998-4061ffb85b11'}
# ####
# What kind of sentence is that: Why did the frog call his insurance company? He had a scratch in his car.
# {'message': 'The sentence "Why did the frog call his insurance company? He had a scratch in his car." is a joke or a riddle. It is structured as a question, followed by a punchline that delivers a humorous twist.\n\n', 'conversation_id': 'd31e3ba7-d49d-4d14-a7df-7ae4a9d7c2c0'}
# ####
# What kind of sentence is that: Why was the computer cold? Because the heater was broken.
# {'message': 'The sentence "Why was the computer cold? Because the heater was broken." is a dialogue or conversation consisting of two sentences.\n\nThe first sentence is an interrogative sentence, which is a type of sentence that asks a question. In this case, the question is "Why was the computer cold?"\n\nThe second sentence is a declarative sentence, which is a type of sentence that makes a statement or expresses a fact. In this case, the statement is "Because the heater was broken."\n\n', 'conversation_id': '161841e6-2627-4f65-ae26-46ddf69ec745'}
# ####
# What kind of sentence is that: Why did the hipster burn his tongue? He drank hot coffee.
# {'message': 'The given sentence is a simple question sentence. It starts with the question word "why" and asks about the reason or cause of a particular event. In this case, the sentence is asking about the reason why the hipster burned his tongue, and the answer is provided in the second sentence that follows.\n\n', 'conversation_id': 'eafc7fdf-baa7-4cc8-baeb-0ceaaae58b7c'}
# ####
# What kind of sentence is that: Why don't oysters give to charity? Because they have no money.
# {'message': 'This is a two-part sentence consisting of a question and an answer. The first part, "Why don\'t oysters give to charity?" is an interrogative sentence because it asks a question. The second part, "Because they have no money," is a declarative sentence because it makes a statement. Together, these two sentences form a complex sentence.\n\n', 'conversation_id': '60c9b43e-c5b5-4ed6-a48f-c44fa3a90f14'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it was sick.
# {'message': 'The sentence "Why did the computer go to the doctor? Because it was sick." is a dialog or a conversation between two people. The first person asks a question, and the second person responds with an answer. This type of sentence is called a declarative sentence, which makes a statement or provides information, in this case, an answer to a question.\n\n', 'conversation_id': '8621c11e-1a65-421b-be44-b2a58d12df02'}
# ####
# What kind of sentence is that: Why did the banana go to the doctor? Because it was sick.
# {'message': 'The sentence "Why did the banana go to the doctor? Because it was sick" is a riddle. It is a type of question that is asked for the purpose of amusing or challenging someone to figure out the answer.\n\n', 'conversation_id': '226bd947-99f5-49f9-905a-719544f203c2'}
# ####
# What kind of sentence is that: Why did the coffee file a police report? Because it got robbed.
# {'message': 'The sentence is a joke or a pun. It plays on the double meaning of the word "robbed", which can mean both "stolen from" and "made very strong or concentrated". The sentence is a play on words, where the coffee "filed a police report" because it was "robbed", meaning it was made too strong. Therefore, the sentence is not a standard grammatical sentence, but rather a humorous play on words.\n\n', 'conversation_id': '79b0d985-36d7-4648-95af-e086725bedfd'}
# ####
# What kind of sentence is that: Why did the golfer bring two pairs of pants? In case one gets damaged.
# {'message': 'The sentence "Why did the golfer bring two pairs of pants? In case one gets damaged." is a complex sentence composed of two clauses:\n\n1. The first clause is an independent clause, "Why did the golfer bring two pairs of pants?", which is a question and could stand on its own as a complete sentence.\n2. The second clause is a dependent clause, "In case one gets damaged", which begins with a subordinating conjunction and cannot stand alone as a complete sentence. This clause functions as an adverbial clause, providing additional information about the reason for the golfer bringing two pairs of pants.\n\nOverall, this is an interrogative complex sentence.\n\n', 'conversation_id': '87a9a372-2240-4960-b5d7-4cb39363ad7c'}
# ####
# What kind of sentence is that: Why don't seagulls fly over the bay? Because they are mostly living in ports.
# {'message': 'The first sentence is an interrogative sentence (a question), while the second sentence is a declarative sentence (a statement).\n\n', 'conversation_id': '06234a15-b2c1-4524-a1c4-640a14add932'}
# ####
# What kind of sentence is that: Why was the belt sent to jail? Because it stole in a store.
# {'message': 'The first sentence, "Why was the belt sent to jail?" is an interrogative sentence, which is a type of sentence that asks a question.\n\nThe second sentence, "Because it stole in a store." is a declarative sentence, which is a type of sentence that makes a statement or gives information.\n\n', 'conversation_id': '4092b29b-41e0-4ea6-8871-5993303da489'}
# ####
# What kind of sentence is that: Why did the computer go to the doctor? Because it had a headache.
# {'message': 'The sentence "Why did the computer go to the doctor? Because it had a headache." is a joke or a riddle, which is a type of humorous sentence that usually involves a play on words or a clever twist.\n\n', 'conversation_id': '9e012a89-5f22-484c-858b-52bfc546f098'}
# ####
# What kind of sentence is that: Why did the chicken go to outer space? To see the moon.
# {'message': 'The given sentence is a joke or a riddle. It is a declarative sentence because it makes a statement, but its purpose is to be humorous rather than to convey factual information.\n\n', 'conversation_id': '10425b2d-3984-47c5-9ae6-e6534aa6730b'}
# ####
# What kind of sentence is that: Why don't skeletons fight each other? They are dead already.
# {'message': 'The given sentence is a complex interrogative sentence. It consists of two clauses: the main clause "They are dead already" and the subordinate clause "Why don\'t skeletons fight each other?". The subordinate clause is a direct question that seeks an explanation, and it functions as the subject of the sentence. The main clause provides the answer or explanation to the question posed in the subordinate clause.\n\n', 'conversation_id': '7d1b45c2-a5bb-4786-ba5f-453efcdb8336'}
# ####
# What kind of sentence is that: What do you call an alligator in a pullpver? A clothed alligator.
# {'message': 'The sentence is a riddle or a joke.\n\n', 'conversation_id': 'a31fb446-7d53-42bb-867f-1a7328824e00'}
# ####
# What kind of sentence is that: Why did the scientist win an award? Because he did very good work.
# {'message': 'The first sentence "Why did the scientist win an award?" is an interrogative sentence, as it asks a question.\n\nThe second sentence "Because he did very good work" is a declarative sentence, as it makes a statement.\n\n', 'conversation_id': '04d462fe-5188-487d-b855-c6d1254b30aa'}
# ####
# What kind of sentence is that: Why did the man turn red? Because he saw the neighbour dressing.
# {'message': 'The given text is a two-part sentence where the first part is an interrogative sentence (a question) and the second part is a declarative sentence (a statement).\n\nThe first part "Why did the man turn red?" is an interrogative sentence as it is asking a question.\n\nThe second part "Because he saw the neighbor dressing" is a declarative sentence as it provides a statement or an explanation in response to the question asked in the first part.\n\n', 'conversation_id': 'adcf62c8-c99f-4aad-b90d-958de4fb0ca8'}
# ####
# What kind of sentence is that: Why was the child sad? Because it had many problems.
# {'message': 'The sentence "Why was the child sad? Because it had many problems." is a complex sentence. It consists of two clauses, an independent clause "Why was the child sad?" and a dependent clause "Because it had many problems." The dependent clause cannot stand alone as a sentence, so it relies on the independent clause to make complete sense.\n\n', 'conversation_id': '09709865-e0aa-4a61-b5d3-dd9646752971'}
# ####
# What kind of sentence is that: Why don't scientists trust journalists? Because they make up everything.
# {'message': 'The given sentence is a complex sentence. It contains a dependent clause "Why don\'t scientists trust journalists?" and an independent clause "Because they make up everything." The dependent clause functions as a question that introduces the topic, and the independent clause provides an answer to the question by giving a reason for the distrust of scientists towards journalists.\n\n', 'conversation_id': '8f5fb02f-0c67-4329-8cd5-45ce0e72b88d'}
# ####
# What kind of sentence is that: Why did the woman go to the doctor? Because she was feeling crumbly.
# {'message': 'The first sentence "Why did the woman go to the doctor?" is an interrogative sentence because it asks a question.\n\nThe second sentence "Because she was feeling crumbly" is a declarative sentence because it makes a statement.\n\n', 'conversation_id': '3f73bc84-b812-4be2-b13d-156b9be00841'}
# ####
# What kind of sentence is that: Why couldn't the man stand up by itself? Because he was drunk.
# {'message': 'The first sentence is an interrogative sentence (a question), while the second sentence is a declarative sentence (a statement). Together, they form a question and answer pair.\n\n', 'conversation_id': '8d306f52-a112-4df0-9c9c-acea9706a128'}
# ####
# What kind of sentence is that: Why did the driver call his insurance company? He had a jump in his car.
# {'message': 'The type of sentence is a compound sentence, consisting of two independent clauses connected by the coordinating conjunction "He".\n\nThe first independent clause is a question: "Why did the driver call his insurance company?"\n\nThe second independent clause is a statement: "He had a jump in his car."\n\nTogether, these two clauses make up a compound sentence that expresses both the question and the reason for the driver\'s action.\n\n', 'conversation_id': '0638b649-7037-4188-9d16-217479ebd9e5'}
# ####
# What kind of sentence is that: Why did the kid cross the playground? To get to the other slide.
# {'message': 'The sentence "Why did the kid cross the playground? To get to the other slide." is a dialog or a conversation between two or more individuals. The first sentence is a question asked by one person, and the second sentence is the response given by another person. This type of sentence structure is commonly used in dialogues, interviews, or casual conversations.\n\n', 'conversation_id': '31e04dab-85eb-4715-8a4e-252e97e90ad0'}
# ####
# What kind of sentence is that: Why was the student cold? Because it was winter.
# {'message': 'The sentence "Why was the student cold? Because it was winter." is a complex sentence consisting of two clauses: a dependent clause and an independent clause.\n\nThe dependent clause is "Why was the student cold?" which is a subordinate clause that functions as a noun clause, serving as the subject of the independent clause.\n\nThe independent clause is "Because it was winter," which is a subordinate clause that functions as an adverbial clause, providing the reason or explanation for why the student was cold.\n\nOverall, the sentence is an example of a complex sentence that contains both a dependent clause and an independent clause.\n\n', 'conversation_id': '300b4d2a-9f3e-4b0e-97c6-7864382e4bdc'}
# ####
# What kind of sentence is that: Why did the coworker burn his tongue? He drank his coffee too hot.
# {'message': 'The given sentence is a complex interrogative sentence. It consists of two clauses: the main clause "He drank his coffee too hot" and the subordinate clause "Why did the coworker burn his tongue?" The subordinate clause is an interrogative clause that asks a question, and the main clause provides the answer to that question.\n\n', 'conversation_id': 'c9e95c17-e3ae-4265-93c9-7d56a92bcf4c'}
# ####
# What kind of sentence is that: Why don't millionaires give to charity? Because they're selfish.
# {'message': 'The sentence "Why don\'t millionaires give to charity? Because they\'re selfish" is a complex sentence. It consists of two clauses, a main clause and a subordinate clause, joined by the subordinating conjunction "because."\n\nThe main clause is "Because they\'re selfish," which provides the reason or explanation for the question posed in the subordinate clause "Why don\'t millionaires give to charity?"\n\nThe sentence expresses a cause-and-effect relationship, with the selfishness of millionaires being the cause for their lack of charitable giving.\n\n', 'conversation_id': '6fe73d60-5269-4ac7-b5d3-4f7f0625aeb3'}
# ####
# What kind of sentence is that: Why did the man go to the doctor? Because he had a virus.
# {'message': 'The first sentence "Why did the man go to the doctor?" is an interrogative sentence because it is a question that asks for information.\n\nThe second sentence "Because he had a virus" is a declarative sentence because it makes a statement and provides an answer to the question in the first sentence.\n\n', 'conversation_id': '0fee82e3-1534-4759-a799-2dbf9c2d8600'}
# ####
# What kind of sentence is that: Why did the teacher go to the doctor? Because it wasn't peeling well.
# {'message': 'The sentence is a play on words or a pun, as it relies on a double meaning of the word "peeling." The sentence can be classified as a joke or a riddle rather than a traditional statement or question.\n\n', 'conversation_id': '325c6c9a-1380-400c-baf0-4dbfef55447d'}
# ####
# What kind of sentence is that: Why did the driver file a police report? Because it got robbed.
# {'message': 'The first sentence "Why did the driver file a police report?" is an interrogative sentence, which asks a question.\n\nThe second sentence "Because it got robbed" is a declarative sentence, which provides an explanation or statement of fact.\n\n', 'conversation_id': '96732474-29fe-4738-aaf3-943884e360dc'}
# ####
# What kind of sentence is that: Why did the athlete bring two pairs of pants? In case one gets dirty.
# {'message': 'The sentence "Why did the athlete bring two pairs of pants? In case one gets dirty." is a complex sentence that consists of two clauses. The first clause is an interrogative clause, which asks a question: "Why did the athlete bring two pairs of pants?" The second clause is a subordinate clause that begins with the conjunction "in case" and explains the reason for bringing two pairs of pants: "in case one gets dirty." This type of subordinate clause is called a conditional clause because it expresses a possible condition or situation.\n\n', 'conversation_id': '4bc77000-1923-4a52-a178-c4b00545cc19'}
# ####
# What kind of sentence is that: Why did the man put his money in the freezer? To hide it from intruders.
# {'message': 'The first sentence, "Why did the man put his money in the freezer?" is an interrogative sentence because it asks a question. The second sentence, "To hide it from intruders," is a declarative sentence because it makes a statement.\n\n', 'conversation_id': '7405406b-0177-4872-b109-7ab0f6b9d879'}
# ####
# What kind of sentence is that: Why don't pigeon fly over the bay? Because they mostly live in cities.
# {'message': 'The first sentence is an interrogative sentence (a question), and the second sentence is a declarative sentence (a statement).\n\n', 'conversation_id': '101837d2-378f-4a63-9c8a-7ab3ea804f3a'}
# ####
# What kind of sentence is that: Why did the daughter go to the seance? To talk to her mother.
# {'message': 'The first sentence "Why did the daughter go to the seance?" is an interrogative sentence, which asks a question.\n\nThe second sentence "To talk to her mother." is a declarative sentence, which provides an answer or statement.\n\n', 'conversation_id': 'b0d7ec33-b6a0-4225-9450-84f24c1b0699'}
# ####
# What kind of sentence is that: Why was the cashier sent to jail? Because she held up a dress.
# {'message': 'The first sentence "Why was the cashier sent to jail?" is an interrogative sentence, which is a sentence that asks a question.\n\nThe second sentence "Because she held up a dress" is a declarative sentence, which is a sentence that makes a statement or provides information.\n\n', 'conversation_id': '39d3e593-ab77-4356-ab10-ed4ee5e58243'}
# ####
# What kind of sentence is that: Why did the man cross the road? To get to the other side.
# {'message': 'The first sentence, "Why did the man cross the road?", is an interrogative sentence because it asks a question. The second sentence, "To get to the other side," is a declarative sentence because it makes a statement.\n\n', 'conversation_id': '5a0239c4-52d6-4861-9e41-8fa71dcf4fca'}
# ####
# What kind of sentence is that: Why did the man go to the doctor? Because he had a bite.
# {'message': 'The first sentence "Why did the man go to the doctor?" is an interrogative sentence as it is asking a question.\n\nThe second sentence "Because he had a bite" is a declarative sentence as it is making a statement.\n\n', 'conversation_id': 'd4a72145-8e36-4d7e-9701-07676ec6f28c'}
# ####
# What kind of sentence is that: Why did the astronaut go to outer space? To see the moon.
# {'message': 'The given sentence is a compound sentence that consists of two independent clauses connected by the conjunction "to." The first independent clause is a question: "Why did the astronaut go to outer space?" The second independent clause is the answer to that question: "To see the moon."\n\n', 'conversation_id': '35185660-f4e1-4491-9f8a-ef1594dce04c'}
# ####
# What kind of sentence is that: Why did the man put bananas in the blender? He wanted to make a smoothie.
# {'message': 'The first sentence, "Why did the man put bananas in the blender?", is an interrogative sentence since it asks a question. The second sentence, "He wanted to make a smoothie", is a declarative sentence since it makes a statement. Together, these sentences form a dialogue where the first sentence asks a question and the second sentence answers it.\n\n', 'conversation_id': '5b005947-110b-45ad-95f6-a84a7bcb7e48'}
# ####
# What kind of sentence is that: Why don't schoolboys fight each other? They don't have the guts.
# {'message': 'The first sentence, "Why don\'t schoolboys fight each other?" is an interrogative sentence, as it asks a question.\n\nThe second sentence, "They don\'t have the guts," is a declarative sentence, as it makes a statement.\n\n', 'conversation_id': 'e8e16772-3a3c-4e7e-b39c-38cfbb44c72a'}
# ####
# What kind of sentence is that: What do you call an man in a vest? A vest wearer.
# {'message': 'The sentence is a question followed by an answer. It is a type of question and answer joke or riddle commonly known as a "pun." The question sets up an expectation for a particular answer, but the answer then subverts that expectation by providing a different, humorous, and often wordplay-based response.\n\n', 'conversation_id': '9fe1ae8e-2b5f-4481-b80a-7aa506f4c3c5'}

# %%
len(all)
alldf.shape
# Out:
# (93, 2)
